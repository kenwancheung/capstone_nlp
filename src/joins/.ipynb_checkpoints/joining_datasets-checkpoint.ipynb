# %% [markdown]
# # JOINS
#
# This jupyter is to join the datasets with their
# one to many notes files.

# %%
import string
import bz2
from os import listdir
from os.path import isfile, join
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import datetime
import nltk.corpus  
import time
import math
import re
import spacy
from functools import reduce
from nltk.text import Text
from nltk.corpus import stopwords
from itertools import combinations
from textblob import TextBlob
from textblob.sentiments import NaiveBayesAnalyzer
from textblob import TextBlob
from nltk.stem.wordnet import WordNetLemmatizer
# from keras.preprocessing import text, sequence
# from keras.utils import to_categorical
# from keras.layers import Bidirectional, GlobalMaxPool1D,GlobalMaxPool2D, GlobalMaxPool3D,Conv1D, Dense, Input, LSTM, Embedding, Dropout, Activation
# from keras.models import Model, Sequential
# from keras.callbacks import EarlyStopping, ModelCheckpoint
# %matplotlib inline
plt.style.use('fivethirtyeight')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\t.cri.kcheung\\capstone_nlp\\src\\joins'

# %%
# get all files in subfolder
mypath = "Z:/FINAL OUTPUT v2/"
onlyfiles = [join(mypath,f) for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
onlyfiles
# Out:
# ['Z:/FINAL OUTPUT v2/07_ENCOUNTER_SOCIAL_HX_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/09_DX_INFO_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/merged_cohort1.csv',
#  'Z:/FINAL OUTPUT v2/05_ENCOUNTER_PROVIDER_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/04_ENCOUNTER_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/06_ENCOUNTER_PROVIDER_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/02_PATIENT_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/merged_cohort2.csv',
#  'Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_2_NEW.csv',
#  'Z:/FINAL OUTPUT v2/03_ENCOUNTER_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/11_COHORT_1_RADIOLOGY.csv',
#  'Z:/FINAL OUTPUT v2/08_ENCOUNTER_SOCIAL_HX_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/10_DX_INFO_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/12_COHORT_2_RADIOLOGY.csv']

# %% [markdown]
# # Modular

# %%
onlyfiles_sorted = sorted(onlyfiles, key=lambda x:(x!="PATIENT_COHORT", x))

# %%
frame = pd.DataFrame()
list_ = []

def readin(listoffiles,like):
    for f in listoffiles:
        if f.find(like) == -1:
            print("skipped:",f)
        else:
            print("processed",f)
            df = pd.read_csv(f,index_col=None, header=0,sep="|")
            df.columns = [x.lower() for x in df.columns]
            list_.append(df)
    suffix = ('_patient', '_encounter', '_encounter_provider', '_encounter_social','_dx_info','_radiology')
    for i in range(0,len(list_)):
        print(i)
        tmp1 = pd.DataFrame(list_[i].iloc[:,0])
#         print(tmp1)
        list_[i] = list_[i].iloc[:,1:].add_suffix(suffix[i])
        list_[i] = pd.concat((tmp1,(list_[i])),axis=1)
    frame = reduce(lambda x, y: pd.merge(x, y, on = 'patient_id',how="left"), list_)
    return(frame)

# %%
cohort1_dta = readin(onlyfiles_sorted,"COHORT_1")
# Out:
# processed Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_1.csv
# skipped: Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_2_NEW.csv
# skipped: Z:/FINAL OUTPUT v2/02_PATIENT_COHORT_2.csv
# processed Z:/FINAL OUTPUT v2/03_ENCOUNTER_COHORT_1.csv
# skipped: Z:/FINAL OUTPUT v2/04_ENCOUNTER_COHORT_2.csv
# processed Z:/FINAL OUTPUT v2/05_ENCOUNTER_PROVIDER_COHORT_1.csv
# skipped: Z:/FINAL OUTPUT v2/06_ENCOUNTER_PROVIDER_COHORT_2.csv
# processed Z:/FINAL OUTPUT v2/07_ENCOUNTER_SOCIAL_HX_COHORT_1.csv
# skipped: Z:/FINAL OUTPUT v2/08_ENCOUNTER_SOCIAL_HX_COHORT_2.csv
# processed Z:/FINAL OUTPUT v2/09_DX_INFO_COHORT_1.csv
# skipped: Z:/FINAL OUTPUT v2/10_DX_INFO_COHORT_2.csv
# processed Z:/FINAL OUTPUT v2/11_COHORT_1_RADIOLOGY.csv
# skipped: Z:/FINAL OUTPUT v2/12_COHORT_2_RADIOLOGY.csv
# skipped: Z:/FINAL OUTPUT v2/merged_cohort1.csv
# skipped: Z:/FINAL OUTPUT v2/merged_cohort2.csv
# 0
# 1
# 2
# 3
# 4
# 5

# %%
cohort1_dta.shape
# Out:
# (106212, 119)

# %%
cohort1_dta.head()
# Out:
#    patient_id  age_at_last_encounter_patient gender_patient  \
# 0       32124                           90.0              F
# 1       32124                           90.0              F
# 2       32124                           90.0              F
# 3       32124                           90.0              F
# 4       74912                           63.0              F
#
#              race_patient       ethnicity_patient date_of_death_d_patient  \
# 0                   White  Not Hispanic or Latino                     NaN
# 1                   White  Not Hispanic or Latino                     NaN
# 2                   White  Not Hispanic or Latino                     NaN
# 3                   White  Not Hispanic or Latino                     NaN
# 4  Black/African-American  Not Hispanic or Latino                     NaN
#
#    encounter_id_encounter enc_eio_encounter visit_status_1_encounter  \
# 0                 5039107                 O                Completed
# 1                 5039107                 O                Completed
# 2                 5039107                 O                Completed
# 3                 5039107                 O                Completed
# 4                 5237464                 O                Completed
#
#   visit_status_2_encounter           ...           dx_12_dx_info  \
# 0                      NaN           ...                     NaN
# 1                      NaN           ...                     NaN
# 2                      NaN           ...                     NaN
# 3                      NaN           ...                     NaN
# 4                      NaN           ...                     NaN
#
#    dx_desc_12_dx_info dx12_rank_dx_info dx_13_dx_info dx_desc_13_dx_info  \
# 0                 NaN               NaN           NaN                NaN
# 1                 NaN               NaN           NaN                NaN
# 2                 NaN               NaN           NaN                NaN
# 3                 NaN               NaN           NaN                NaN
# 4                 NaN               NaN           NaN                NaN
#
#   dx13_rank_dx_info encounter_id_radiology order_proc_id_deid_radiology  \
# 0               NaN                    NaN                          NaN
# 1               NaN                    NaN                          NaN
# 2               NaN                    NaN                          NaN
# 3               NaN                    NaN                          NaN
# 4               NaN                    NaN                          NaN
#
#    ordering_date_off_radiology exam_type\t\t_radiology
# 0                          NaN                     NaN
# 1                          NaN                     NaN
# 2                          NaN                     NaN
# 3                          NaN                     NaN
# 4                          NaN                     NaN
#
# [5 rows x 119 columns]

# %%
cohort1_dta.encounter_id_radiology
# Out:
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN
# 10              NaN
# 11              NaN
# 12              NaN
# 13              NaN
# 14              NaN
# 15              NaN
# 16              NaN
# 17              NaN
# 18        6862790.0
# 19        6862790.0
# 20        6862790.0
# 21              NaN
# 22              NaN
# 23              NaN
# 24              NaN
# 25              NaN
# 26              NaN
# 27              NaN
# 28              NaN
# 29              NaN
#             ...
# 106182    8425699.0
# 106183    8425699.0
# 106184    8425699.0
# 106185    8425699.0
# 106186    8425699.0
# 106187    8425699.0
# 106188    8425699.0
# 106189    8425699.0
# 106190    8425699.0
# 106191    8425699.0
# 106192    8425699.0
# 106193    8425699.0
# 106194    8425699.0
# 106195    8425699.0
# 106196    8425699.0
# 106197    8425699.0
# 106198    8425699.0
# 106199    8425699.0
# 106200    8425699.0
# 106201    8425699.0
# 106202    8425699.0
# 106203    8425699.0
# 106204    8425699.0
# 106205    8425699.0
# 106206    8425699.0
# 106207    8425699.0
# 106208    8425699.0
# 106209    8425699.0
# 106210    8425699.0
# 106211    8425699.0
# Name: encounter_id_radiology, Length: 106212, dtype: float64

# %%
cohort1_dta.iloc[80000,0:]
# Out:
# patient_id                                                                                    1557194
# age_at_last_encounter_patient                                                                      41
# gender_patient                                                                                      F
# race_patient                                                                     Asian/Mideast Indian
# ethnicity_patient                                                              Not Hispanic or Latino
# date_of_death_d_patient                                                                           NaN
# encounter_id_encounter                                                                        5403357
# enc_eio_encounter                                                                                   O
# visit_status_1_encounter                                                                    Completed
# visit_status_2_encounter                                                                          NaN
# visit_status_3_encounter                                                                          NaN
# visit_status_4_encounter                                                                          NaN
# adm_date_d_encounter                                                          2012-06-29 00:00:00.000
# disc_date_d_encounter                                                         2012-06-29 00:00:00.000
# start_date_d_encounter                                                        2012-06-29 00:00:00.000
# end_date_d_encounter                                                          2012-06-29 00:00:00.000
# admit_source_1_encounter                                     Non-Health Care Facility Point of Origin
# admit_source_2_encounter                                                                          NaN
# admit_source_3_encounter                                                                          NaN
# disch_disp_1_encounter                                                                            NaN
# disch_disp_2_encounter                                                                            NaN
# disch_disp_3_encounter                                                                            NaN
# zip_d_encounter                                                                                100091
# enc_fin_class_encounter                                                            Managed Care - PPO
# encounter_id_encounter_provider                                                               4992137
# admitting_prov_id_encounter_provider                                                              NaN
# admitting_provider_department_encounter_provider                                                  NaN
# attnd_prov_id_encounter_provider                                                                 2873
# attending_department_encounter_provider                                              BSD EH PULMONARY
# referring_prov_id_encounter_provider                                                             2873
#                                                                           ...
# dx_desc_5_dx_info                                                                           HYPOXEMIA
# dx5_rank_dx_info                                                                                    5
# dx_6_dx_info                                                                                   564.00
# dx_desc_6_dx_info                                                            UNSPECIFIED CONSTIPATION
# dx6_rank_dx_info                                                                                    6
# dx_7_dx_info                                                                                   516.34
# dx_desc_7_dx_info                                   RESPIRATORY BRONCHIOLITIS INTERSTITIAL LUNG DI...
# dx7_rank_dx_info                                                                                    7
# dx_8_dx_info                                                                                      NaN
# dx_desc_8_dx_info                                                                                 NaN
# dx8_rank_dx_info                                                                                  NaN
# dx_9_dx_info                                                                                      NaN
# dx_desc_9_dx_info                                                                                 NaN
# dx9_rank_dx_info                                                                                  NaN
# dx_10_dx_info                                                                                     NaN
# dx_desc_10_dx_info                                                                                NaN
# dx10_rank_dx_info                                                                                 NaN
# dx_11_dx_info                                                                                     NaN
# dx_desc_11_dx_info                                                                                NaN
# dx11_rank_dx_info                                                                                 NaN
# dx_12_dx_info                                                                                     NaN
# dx_desc_12_dx_info                                                                                NaN
# dx12_rank_dx_info                                                                                 NaN
# dx_13_dx_info                                                                                     NaN
# dx_desc_13_dx_info                                                                                NaN
# dx13_rank_dx_info                                                                                 NaN
# encounter_id_radiology                                                                    5.40336e+06
# order_proc_id_deid_radiology                                                                   654602
# ordering_date_off_radiology                                                   2012-06-29 00:00:00.000
# exam_type\t\t_radiology                                                       XR Chest PA/Lateral\t\t
# Name: 80000, Length: 119, dtype: object

# %%
cohort1_dta.columns
# Out:
# Index(['patient_id', 'age_at_last_encounter_patient', 'gender_patient',
#        'race_patient', 'ethnicity_patient', 'date_of_death_d_patient',
#        'encounter_id_encounter', 'enc_eio_encounter',
#        'visit_status_1_encounter', 'visit_status_2_encounter',
#        ...
#        'dx_12_dx_info', 'dx_desc_12_dx_info', 'dx12_rank_dx_info',
#        'dx_13_dx_info', 'dx_desc_13_dx_info', 'dx13_rank_dx_info',
#        'encounter_id_radiology', 'order_proc_id_deid_radiology',
#        'ordering_date_off_radiology', 'exam_type\t\t_radiology'],
#       dtype='object', length=119)

# %% [markdown]
# ### Prior to loading in lets check for j84.

# %%
onlyfiles_sorted[10]
# Out:
# 'Z:/FINAL OUTPUT v2/10_DX_INFO_COHORT_2.csv'

# %%
cohort2_icd_check = pd.read_csv(onlyfiles_sorted[10],sep="|")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (98,110,113,116,117,119,120,122,123,125,126,128,129,131,132,134,135,137,138,140,141,143,144,146,147,149,150,152,153,155,156,158,159,161,162,164,165,167,168,170,171,173,174,176,177,179,180,182,183,185,186,188,189,191,192,194,195,197,198,200,201,203,204,206,207,209,210,212,213,215,216,218,219,221,222,224,225,227,228,230,231,233,234,236,237,239,240,242,243,245,246,248,249,251,252,254,255,257,258) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# get list of columns with dx
dx_cols = [col for col in cohort2_icd_check.columns if 'dx_' in col]
dx_cols[0]
# Out:
# 'dx_1'

# %%
# all icd codes list
icd_codes_list = ['495','4951','4952','4953','4954','4955','4956','4957','4958','4959','496','515','517','5171','5172','5173','5178','516','5160','5161','5162','5163','51630','51631','51632','51633','51634','51635','51636','51637','5164','5165','5166','51661','51662','51663','51664','51669','5168','5169','J670','J671','J672','J673','J674','J675','J676','J677','J678','J679','J6710','J8410','J8489','J17','M3481','J99','J8401','J8402','J8403','J84111','J84112','J84113','J84114','J84115','J84116','J84117','J8481','J8482','J8483','J84841','J84842','J84843','J84844','J84845','J84848','J8409','J849']
pattern = '|'.join(icd_codes_list)

# %%
# extract all
icd_subset = []

for col in dx_cols:
#     print(col)
    tmpdf = cohort2_icd_check[cohort2_icd_check[col].str.contains(pattern,na=False)]
    icd_subset.append(tmpdf)
# print(icd_subset)

# %%
icd_subset_df = icd_subset[0]

# %%
len(np.unique(icd_subset_df.PATIENT_ID))
# Out:
# 2243

# %% [markdown]
# # Now i have all the patients with the relevant icd codes. Around 2k unique of them.
#
# We need to extract all of the relevant records into their own df. Let's tweak the merging into just those of which that are in the lsit of patients.

# %%
onlyfiles_sorted
# Out:
# ['Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_2_NEW.csv',
#  'Z:/FINAL OUTPUT v2/02_PATIENT_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/03_ENCOUNTER_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/04_ENCOUNTER_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/05_ENCOUNTER_PROVIDER_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/06_ENCOUNTER_PROVIDER_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/07_ENCOUNTER_SOCIAL_HX_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/08_ENCOUNTER_SOCIAL_HX_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/09_DX_INFO_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/10_DX_INFO_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/11_COHORT_1_RADIOLOGY.csv',
#  'Z:/FINAL OUTPUT v2/12_COHORT_2_RADIOLOGY.csv',
#  'Z:/FINAL OUTPUT v2/merged_cohort1.csv',
#  'Z:/FINAL OUTPUT v2/merged_cohort2.csv']

# %%
cohort2move = pd.read_csv(onlyfiles_sorted[2],sep="|")
cohort2move.head()
# Out:
#    PATIENT_ID  AGE_AT_LAST_ENCOUNTER gender                    race  \
# 0          49                   79.0      M                   White
# 1          99                   86.0      F                   White
# 2         104                   84.0      M                   White
# 3         114                   66.0      F                   White
# 4         118                   92.0      F  Black/African-American
#
#                 ETHNICITY DATE_OF_DEATH_D
# 0  Not Hispanic or Latino             NaN
# 1  Not Hispanic or Latino             NaN
# 2  Not Hispanic or Latino             NaN
# 3  Not Hispanic or Latino             NaN
# 4  Not Hispanic or Latino             NaN

# %%
cohort2movedf = cohort2move[cohort2move.PATIENT_ID.isin(icd_subset_df.PATIENT_ID)]

# %%
cohort2movedf.to_csv(join(mypath,"01_PATIENT_COHORT_1_MOVEDFROMCOHORT2.csv"),sep="|",index=False)

# %% [markdown]
# ### Prior to loading in the second cohort let's randomly sample in 10k rows

# %%
cohort2move.head()
# Out:
#    PATIENT_ID  AGE_AT_LAST_ENCOUNTER gender                    race  \
# 0          49                   79.0      M                   White
# 1          99                   86.0      F                   White
# 2         104                   84.0      M                   White
# 3         114                   66.0      F                   White
# 4         118                   92.0      F  Black/African-American
#
#                 ETHNICITY DATE_OF_DEATH_D
# 0  Not Hispanic or Latino             NaN
# 1  Not Hispanic or Latino             NaN
# 2  Not Hispanic or Latino             NaN
# 3  Not Hispanic or Latino             NaN
# 4  Not Hispanic or Latino             NaN

# %%
cohort2removeddf = cohort2move[~cohort2move.PATIENT_ID.isin(icd_subset_df.PATIENT_ID)]

# %%
cohort2sampdf = cohort2removeddf.sample(n=30000,random_state=10,replace=False)
cohort2sampdf.shape
# Out:
# (30000, 6)

# %%
cohort2sampdf.to_csv(join(mypath,"01_PATIENT_COHORT_2_NEW.csv"),sep="|")

# %% [markdown]
# # Next step we need to create a join list with just the ids in moved from cohort2 set
#
# Then we can merge them into a consolidated cohort1

# %%
onlyfiles2 = [join(mypath,f) for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
onlyfiles2
# Out:
# ['Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_1_MOVEDFROMCOHORT2.csv',
#  'Z:/FINAL OUTPUT v2/07_ENCOUNTER_SOCIAL_HX_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/09_DX_INFO_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/merged_cohort1.csv',
#  'Z:/FINAL OUTPUT v2/05_ENCOUNTER_PROVIDER_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/04_ENCOUNTER_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/06_ENCOUNTER_PROVIDER_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/02_PATIENT_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/merged_cohort2.csv',
#  'Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_2_NEW.csv',
#  'Z:/FINAL OUTPUT v2/03_ENCOUNTER_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/11_COHORT_1_RADIOLOGY.csv',
#  'Z:/FINAL OUTPUT v2/08_ENCOUNTER_SOCIAL_HX_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/10_DX_INFO_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/12_COHORT_2_RADIOLOGY.csv']

# %%
onlyfiles2edit = list( onlyfiles2[i] for i in [0, 6, 7, 8, 13,14,15] )
# onlyfiles2edit = list( onlyfiles2[i] for i in [0,15] )

# %%
onlyfiles2edit
# Out:
# ['Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_1_MOVEDFROMCOHORT2.csv',
#  'Z:/FINAL OUTPUT v2/04_ENCOUNTER_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/06_ENCOUNTER_PROVIDER_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/02_PATIENT_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/08_ENCOUNTER_SOCIAL_HX_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/10_DX_INFO_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/12_COHORT_2_RADIOLOGY.csv']

# %%
frame = pd.DataFrame()
list_ = []

def readin(listoffiles,like):
    for f in listoffiles:
        if f.find(like) == -1:
            print("skipped:",f)
        else:
            print("added to list_",f)
            df = pd.read_csv(f,index_col=None, header=0,sep="|")
            df.columns = [x.lower() for x in df.columns]
            list_.append(df)
    suffix = ('_patient', '_encounter', '_encounter_provider', '_encounter_social','_dx_info','_radiology')
    for i in range(0,len(list_)):
        print("iteration number",i)
        tmp1 = pd.DataFrame(list_[i].iloc[:,0])
        print(tmp1)
        list_[i] = list_[i].iloc[:,1:].add_suffix(suffix[i])
        list_[i] = pd.concat((tmp1,(list_[i])),axis=1)
    frame = reduce(lambda x, y: pd.merge(x, y, on = 'patient_id',how="left"), list_)
    return(frame)

# %%
list_[6].iloc[:,0]
# Out:
# 0           155043
# 1           155043
# 2          1399257
# 3          1399257
# 4          1764333
# 5          1764333
# 6          1764333
# 7          1764333
# 8          1420442
# 9          1420442
# 10         1681824
# 11         1681824
# 12         1681824
# 13         1858299
# 14         1858299
# 15         1858299
# 16         1858299
# 17         1445603
# 18         1445603
# 19         1445603
# 20         1445603
# 21         1102681
# 22         1499273
# 23         1499273
# 24         1335714
# 25         1766157
# 26         1766157
# 27          723436
# 28          723436
# 29         1874926
#             ...
# 1275918    2270124
# 1275919    2270124
# 1275920    2270124
# 1275921    2270124
# 1275922    2270124
# 1275923    2270124
# 1275924    2270124
# 1275925    2270124
# 1275926    2270124
# 1275927    2379569
# 1275928    2379569
# 1275929    2379569
# 1275930    2379569
# 1275931    1576038
# 1275932    1576038
# 1275933    1576038
# 1275934    1576038
# 1275935     829868
# 1275936     829868
# 1275937     544706
# 1275938     544706
# 1275939    2490228
# 1275940    2490228
# 1275941     136323
# 1275942     136323
# 1275943     136323
# 1275944     136323
# 1275945     536175
# 1275946    2341190
# 1275947    2341190
# Name: patient_id, Length: 1275948, dtype: int64

# %%
list_[6].iloc[:,1:].add_suffix(suffix[i]
# Out:
#          encounter_id  order_proc_id_deid        ordering_date_off  \
# 0              155164              393037  2013-04-26 00:00:00.000
# 1              155164              563004  2013-04-26 00:00:00.000
# 2             1214909              228000  2015-12-27 00:00:00.000
# 3             1214909             1249360  2015-12-27 00:00:00.000
# 4             2837972              433970  2014-11-02 00:00:00.000
# 5             2837972              560741  2014-11-01 00:00:00.000
# 6             2837972              563825  2014-11-02 00:00:00.000
# 7             2837972              997086  2014-11-01 00:00:00.000
# 8             3594921              588520  2012-10-24 00:00:00.000
# 9             3594921             1089068  2012-10-24 00:00:00.000
# 10            3599599              727666  2012-12-29 00:00:00.000
# 11            3599599             1082607  2012-12-29 00:00:00.000
# 12            3599599             1148074  2012-12-29 00:00:00.000
# 13            3730467              108127  2013-01-31 00:00:00.000
# 14            3730467              652099  2013-01-31 00:00:00.000
# 15            3730467              726782  2013-01-31 00:00:00.000
# 16            3730467             1035335  2013-01-31 00:00:00.000
# 16                      CT Chest & Upper Abdomen w
# 17                    CT Head & Soft Tissue Neck w
# 18                      CT Chest & Upper Abdomen w
# 19                    CT Head & Soft Tissue Neck w
# 20                      CT Chest & Upper Abdomen w
# 21                      CT Chest & Upper Abdomen w
# 22                     CT Chest, Abdomen, Pelvis w
# 23                     CT Chest, Abdomen, Pelvis w
# 24                             XR Chest PA/Lateral
# 25                      CT Chest & Upper Abdomen w
# 26                      CT Chest & Upper Abdomen w
# 27                        CT CHEST AND UPPER ABD W
# 28                        CT CHEST AND UPPER ABD W
# 29                             XR Chest PA/Lateral
# ...                                            ...
# 1275918                                 CT Head wo
# 1275919                      XR Port Chest, 1 View
# 1275920   XR PORT ABD COMP DECUB AND OR ERCT MIN2V
# 1275921                                 CT Head wo
# 1275922                      XR Port Chest, 1 View
# 1275923                CT Upper Abdomen & Pelvis w
# 1275924                   XR Portable Chest, 1View
# 1275925                   XR Portable Chest, 1View
# 1275926   XR PORT ABD COMP DECUB AND OR ERCT MIN2V
# 1275927                        XR Chest PA/Lateral
# 1275928                              CT PE Chest w
# 1275929                              CT PE Chest w
# 1275930                        XR Chest PA/Lateral
# 1275931                CT Upper Abdomen & Pelvis w
# 1275932                        XR Chest PA/Lateral
# 1275933                        XR Chest PA/Lateral
# 1275934                CT Upper Abdomen & Pelvis w
# 1275935                        XR Chest PA/Lateral
# 1275936                        XR Chest PA/Lateral
# 1275937              CT Upper Abdomen & Pelvis WWO
# 1275938              CT Upper Abdomen & Pelvis WWO
# 1275939                                CT Chest wo
# 1275940                                CT Chest wo
# 1275941                CT Upper Abdomen & Pelvis w
# 1275942                CT Upper Abdomen & Pelvis w
# 1275943  XR Abd Complete w Erect & Or Decub min 2v
# 1275944  XR Abd Complete w Erect & Or Decub min 2v
# 1275945                                CT Chest wo
# 1275946                               CT Pelvis wo
# 1275947                               CT Pelvis wo
#
# [1275948 rows x 4 columns]

# %%
cohort1_dta_part2 = readin(onlyfiles2edit,"COHORT")
# Out:
# processed Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_1_MOVEDFROMCOHORT2.csv
# processed Z:/FINAL OUTPUT v2/04_ENCOUNTER_COHORT_2.csv
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2850: DtypeWarning: Columns (6,13,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# processed Z:/FINAL OUTPUT v2/06_ENCOUNTER_PROVIDER_COHORT_2.csv
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2850: DtypeWarning: Columns (2,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# processed Z:/FINAL OUTPUT v2/02_PATIENT_COHORT_2.csv
# processed Z:/FINAL OUTPUT v2/08_ENCOUNTER_SOCIAL_HX_COHORT_2.csv
# processed Z:/FINAL OUTPUT v2/10_DX_INFO_COHORT_2.csv
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:
# 396625     3099825
# 396626     3109516
# 396627     3109745
# 396628     3109756
# 396629     3109776
# 396630     3119597
# 396631     3119766
#
# [396632 rows x 1 columns]
# 6
#          patient_id
# 0            155043
# 1            155043
# 2           1399257
# 3           1399257
# 4           1764333
# 5           1764333
# 6           1764333
# 7           1764333
# 8           1420442
# 9           1420442
# 10          1681824
# 11          1681824
# 12          1681824
# 13          1858299
# 14          1858299
# 15          1858299
# 16          1858299
# 17          1445603
# 18          1445603
# 19          1445603
# 20          1445603
# 21          1102681
# 22          1499273
# 23          1499273
# 24          1335714
# 25          1766157
# 26          1766157
# 27           723436
# 28           723436
# 29          1874926
# ...             ...
# 1275918     2270124
# 1275919     2270124
# 1275920     2270124
# 1275921     2270124
# 1275922     2270124
# 1275923     2270124
# 1275924     2270124
# 1275925     2270124
# 1275926     2270124
# 1275927     2379569
# 1275928     2379569
# 1275929     2379569
# 1275930     2379569
# 1275931     1576038
# 1275932     1576038
# 1275933     1576038
# 1275934     1576038
# 1275935      829868
# 1275936      829868
# 1275937      544706
# 1275938      544706
# 1275939     2490228
# 1275940     2490228
# 1275941      136323
# 1275942      136323
# 1275943      136323
# 1275944      136323
# 1275945      536175
# 1275946     2341190
# 1275947     2341190
# [1275948 rows x 1 columns]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-133-7f12aead3fd8> in <module>()
# ----> 1 cohort1_dta_part2 = readin(onlyfiles2edit,"COHORT")
#
# <ipython-input-132-9082a4d7a976> in readin(listoffiles, like)
#      16         tmp1 = pd.DataFrame(list_[i].iloc[:,0])
#      17         print(tmp1)
# ---> 18         list_[i] = list_[i].iloc[:,1:].add_suffix(suffix[i])
#      19         list_[i] = pd.concat((tmp1,(list_[i])),axis=1)
#      20     frame = reduce(lambda x, y: pd.merge(x, y, on = 'patient_id',how="left"), list_)
#
# IndexError: tuple index out of range

# %%
list_
# Out:
# [      patient_id  age_at_last_encounter_patient gender_patient  \
#  0            114                           66.0              F
#  1            431                           88.0              F
#  2            672                           80.0              M
#  3           1408                           84.0              F
#  4           1549                           80.0              F
#  5           1627                           88.0              M
#  6           2068                           72.0              F
#  7           2276                           76.0              F
#  8           2285                           74.0              M
#  9           3727                           57.0              F
#  10          4612                           82.0              M
#  11          4662                           78.0              F
#  12          4706                           83.0              F
#  13          5797                           56.0              F
#  14          6521                           69.0              M
#  15          6588                           85.0              M
#  16          6911                           74.0              F
#  17          7511                           56.0              F
#  18          7578                           73.0              M
#  19          7708                           61.0              M
#  20          7718                           76.0              F
#  21          7840                           90.0              F
#  22          8306                           87.0              F
#  23          8347                           79.0              F
#  24          8723                           68.0              F
#  25          9482                           79.0              F
#  26         10167                           86.0              F
#  27         10880                           63.0              F
#  28         11485                           82.0              M
#  29         11625                           47.0              F
#  ...          ...                            ...            ...
#  2213     2520175                           75.0              M
#  2214     2520325                           83.0              M
#  2215     2529882                           78.0              M
#  2216     2559644                           47.0              M
#  2217     2569715                           74.0              F
#  2218     2569806                           50.0              F
#  2219     2580003                           61.0              F
#  2220     2589797                           40.0              M
#  2221     2599677                           72.0              F
#  2222     2609629                           58.0              F
#  2223     2610597                           69.0              F
#  2224     2620804                           80.0              F
#  2225     2629684                           64.0              M
#  2226     2629713                           72.0              M
#  2227     2629846                           70.0              M
#  2228     2640111                           67.0              M
#  2229     2640819                           81.0              F
#  2230     2659902                           63.0              M
#  2231     2669493                           46.0              F
#  2232     2670537                           45.0              M
#  2233     2690083                           64.0              M
#  2234     2690614                           67.0              F
#  2235     2710496                           78.0              F
#  2236     2710878                           60.0              M
#  2237     2720035                           66.0              F
#  2238     2739777                           67.0              M
#  2239     2740460                           40.0              M
#  2240     2779581                           74.0              M
#  2241     2849686                           56.0              M
#  2242     2959602                           64.0              M
#
#                  race_patient       ethnicity_patient  date_of_death_d_patient
#  0                      White  Not Hispanic or Latino                      NaN
#  1     Black/African-American  Not Hispanic or Latino                      NaN
#  2       Asian/Mideast Indian  Not Hispanic or Latino                      NaN
#  3     Black/African-American  Not Hispanic or Latino                      NaN
#  4     Black/African-American  Not Hispanic or Latino                      NaN
#  5     Black/African-American  Not Hispanic or Latino                      NaN
#  6                      White  Not Hispanic or Latino                      NaN
#  7     Black/African-American  Not Hispanic or Latino                      NaN
#  8                      White  Not Hispanic or Latino                      NaN
#  9     Black/African-American  Not Hispanic or Latino  2014-05-04 00:00:00.000
#  10    Black/African-American  Not Hispanic or Latino  2017-03-07 00:00:00.000
#  11    Black/African-American  Not Hispanic or Latino                      NaN
#  12    Black/African-American  Not Hispanic or Latino                      NaN
#  13    Black/African-American  Not Hispanic or Latino                      NaN
#  14    Black/African-American  Not Hispanic or Latino                      NaN
#  15    Black/African-American  Not Hispanic or Latino                      NaN
#  16    Black/African-American  Not Hispanic or Latino                      NaN
#  17    Black/African-American  Not Hispanic or Latino  2014-07-01 00:00:00.000
#  18    Black/African-American  Not Hispanic or Latino                      NaN
#  19    Black/African-American  Not Hispanic or Latino                      NaN
#  20    Black/African-American  Not Hispanic or Latino                      NaN
#  21    Black/African-American  Not Hispanic or Latino                      NaN
#  22    Black/African-American  Not Hispanic or Latino                      NaN
#  23                     White  Not Hispanic or Latino                      NaN
#  24    Black/African-American  Not Hispanic or Latino                      NaN
#  25    Black/African-American        Patient Declined                      NaN
#  26    Black/African-American  Not Hispanic or Latino  2015-03-15 00:00:00.000
#  27    Black/African-American  Not Hispanic or Latino                      NaN
#  28    Black/African-American  Not Hispanic or Latino                      NaN
#  29    Black/African-American  Not Hispanic or Latino                      NaN
#  ...                      ...                     ...                      ...
#  2213                   White  Not Hispanic or Latino                      NaN
#  2214                   White  Not Hispanic or Latino                      NaN
#  2215                   White  Not Hispanic or Latino                      NaN
#  2216  Black/African-American  Not Hispanic or Latino                      NaN
#  2217                   White  Not Hispanic or Latino                      NaN
#  2218                   White  Not Hispanic or Latino                      NaN
#  2219  Black/African-American  Not Hispanic or Latino                      NaN
#  2220  Black/African-American  Not Hispanic or Latino                      NaN
#  2221  Black/African-American  Not Hispanic or Latino                      NaN
#  2222  Black/African-American  Not Hispanic or Latino                      NaN
#  2223                   White  Not Hispanic or Latino                      NaN
#  3                     Completed                 Canceled
#  4                     Completed                      NaN
#  5                     Completed                      NaN
#  6                     Completed                 Canceled
#  7                     Completed                      NaN
#  8                     Completed                      NaN
#  9                       No Show                Completed
#  10                    Completed                      NaN
#  11                    Completed                 Canceled
#  12                    Completed                      NaN
#  13                    Completed                 Canceled
#  14                    Completed                 Canceled
#  15                    Completed                      NaN
#  16                    Completed                 Canceled
#  17                    Completed                      NaN
#  18                    Completed                      NaN
#  19                      No Show                Completed
#  20                    Completed                      NaN
#  21                    Completed                      NaN
#  22                    Completed                      NaN
#  23                    Completed                      NaN
#  24                    Completed                      NaN
#  25                    Completed                      NaN
#  26                    Completed                      NaN
#  27                    Completed                 Canceled
#  28                    Completed                 Canceled
#  29                    Completed                 Canceled
#  ...                         ...                      ...
#  396602                Completed                      NaN
#  396603                Completed                      NaN
#  396604                Completed                      NaN
#  396605                Completed                      NaN
#  396606                Completed                      NaN
#  396607                Completed                      NaN
#  396608                  No Show                Completed
#  396609                Completed                      NaN
#  396610                Completed                      NaN
#  396611                Completed                      NaN
#  396612                Completed                      NaN
#  396613                Completed                 Canceled
#  396614                Completed                      NaN
#  396615                Completed                      NaN
#  396616                Completed                      NaN
#  396617                Completed                      NaN
#  396618                Completed                      NaN
#  396619                Completed                      NaN
#  396620                Completed                 Canceled
#  396621                  No Show                Completed
#  396622                Completed                      NaN
#  396623                Completed                      NaN
#  396624                Completed                      NaN
#  396625                Completed                      NaN
#  396626                Completed                      NaN
#  396627                Completed                      NaN
#  396628                Completed                      NaN
#  396629                Completed                      NaN
#  396630                Completed                      NaN
#  396631                Completed                      NaN
#
#         visit_status_3_encounter visit_status_4_encounter  \
#  0                           NaN                      NaN
#  1                           NaN                      NaN
#  2                           NaN                      NaN
#  3                           NaN                      NaN
#  4                           NaN                      NaN
#  5                           NaN                      NaN
#  6                           NaN                      NaN
#  7                           NaN                      NaN
#  8                           NaN                      NaN
#  9                      Canceled                      NaN
#  10                          NaN                      NaN
#  11                          NaN                      NaN
#  12                          NaN                      NaN
#  13                          NaN                      NaN
#  14                          NaN                      NaN
#  15                          NaN                      NaN
#  16                          NaN                      NaN
#  17                          NaN                      NaN
#  18                          NaN                      NaN
#  19                     Canceled                      NaN
#  20                          NaN                      NaN
#  21                          NaN                      NaN
#  22                          NaN                      NaN
#  23                          NaN                      NaN
#  24                          NaN                      NaN
#  25                          NaN                      NaN
#  26                          NaN                      NaN
#  27                          NaN                      NaN
#  28                          NaN                      NaN
#  29                          NaN                      NaN
#  ...                         ...                      ...
#  396602                      NaN                      NaN
#  396603                      NaN                      NaN
#  396604                      NaN                      NaN
#  396605                      NaN                      NaN
#  396606                      NaN                      NaN
#  396607                      NaN                      NaN
#  396608                 Canceled                      NaN
#  396609                      NaN                      NaN
#  396610                      NaN                      NaN
#  396611                      NaN                      NaN
#  396612                      NaN                      NaN
#  396613                      NaN                      NaN
#  396614                      NaN                      NaN
#  396615                      NaN                      NaN
#  396616                      NaN                      NaN
#  396617                      NaN                      NaN
#  396618                      NaN                      NaN
#  396619                      NaN                      NaN
#  12                        NaN           113043
#  13                        NaN           113043
#  14                        NaN           113043
#  15                        NaN           113043
#  16                        NaN           113043
#  17                        NaN           113043
#  18                        NaN           113043
#  19                        NaN           113043
#  20                        NaN           113043
#  21                        NaN           149109
#  22                        NaN           149109
#  23                        NaN           149109
#  24                        NaN           149109
#  25                        NaN           210554
#  26                        NaN           210554
#  27                        NaN           210554
#  28                        NaN           210554
#  29                        NaN           210554
#  ...                       ...              ...
#  396602                    NaN           173951
#  396603                    NaN           185603
#  396604                    NaN           175244
#  396605                    NaN           146111
#  396606                    NaN           109909
#  396607                    NaN           105385
#  396608                    NaN           100776
#  396609                    NaN           154430
#  396610                    NaN           154430
#  396611                    NaN           195758
#  396612                    NaN           142179
#  396613                    NaN           100817
#  396614                    NaN           110327
#  396615                    NaN           187885
#  396616                    NaN           140137
#  396617                    NaN           140137
#  396618                    NaN           172366
#  396619                    NaN           127423
#  396620                    NaN           149682
#  396621                    NaN           121411
#  396622                    NaN           105096
#  396623                    NaN           194099
#  396624                    NaN           108311
#  396625                    NaN           153045
#  396626                    NaN           162141
#  396627                    NaN           155124
#  396628                    NaN           163512
#  396629                    NaN           213333
#  396630                    NaN           179870
#  396631                    NaN           179188
#
#                   enc_fin_class_encounter
#  0                               Medicare
#  1                               Medicare
#  2                               Medicare
#  3                               Medicare
#  4                               Medicare
#  5                               Medicare
#  6                               Medicare
#  7                               Medicare
#  8                               Medicare
#  9                               Medicare
#  10                              Medicare
#  11                              Medicare
#  12                              Medicare
#  13                              Medicare
#  14                              Medicare
#  15                              Medicare
#  16                              Medicare
#  17                              Medicare
#  18      BLUE CROSS/BLUE SHIELD, MEDICARE
#  19      BLUE CROSS/BLUE SHIELD, MEDICARE
#  20      BLUE CROSS/BLUE SHIELD, MEDICARE
#  21              Blue Cross / Blue Shield
#  22                    Managed Care - POS
#  23                              Medicare
#  24                    Managed Care - POS
#  25                              Medicare
#  26                              Medicare
#  27                              Medicare
#  28                              Medicare
#  29                              Medicare
#  ...                                  ...
#  396602                          MEDICAID
#  396603                          MEDICAID
#  396604                MEDICAID, MEDICARE
#  396605            BLUE CROSS/BLUE SHIELD
#  396606                          MEDICAID
#  396607                          MEDICAID
#  396608                          MEDICAID
#  396609                          MEDICARE
#  396610                          MEDICARE
#  396611                          MEDICARE
#  396612                    PRIVATE PAYORS
#  396613                MEDICAID, MEDICARE
#  396614                          MEDICARE
#  396615                    PRIVATE PAYORS
#  396616            BLUE CROSS/BLUE SHIELD
#  396617            BLUE CROSS/BLUE SHIELD
#  396618            BLUE CROSS/BLUE SHIELD
#  396619                          MEDICAID
#  396620                    PRIVATE PAYORS
#  396621                          MEDICAID
#  396622                          MEDICARE
#  396623                          MEDICARE
#  396624                          MEDICARE
#  396625            BLUE CROSS/BLUE SHIELD
#  396626                          MEDICAID
#  396627                          MEDICAID
#  396628                    PRIVATE PAYORS
#  396629                    PRIVATE PAYORS
#  396630            BLUE CROSS/BLUE SHIELD
#  396631                    PRIVATE PAYORS
#
#  [396632 rows x 19 columns],
#  1275943      136323      12596904             1050961
#  1275944      136323      12596904             1211140
#  1275945      536175      12847872              550730
#  1275946     2341190      12977749             1395603
#  1275947     2341190      12977749             1397152
#
#                 ordering_date_off                                  exam_type
#  0        2013-04-26 00:00:00.000                    CT Upper Abd & Pelvis w
#  1        2013-04-26 00:00:00.000                    CT Upper Abd & Pelvis w
#  2        2015-12-27 00:00:00.000                  XR Portable Chest, 1 View
#  3        2015-12-27 00:00:00.000                  XR Portable Chest, 1 View
#  4        2014-11-02 00:00:00.000                      XR Port Chest, 1 View
#  5        2014-11-01 00:00:00.000                      XR Port Chest, 1 View
#  6        2014-11-02 00:00:00.000                      XR Port Chest, 1 View
#  7        2014-11-01 00:00:00.000                      XR Port Chest, 1 View
#  8        2012-10-24 00:00:00.000                   CT CHEST AND UPPER ABD W
#  9        2012-10-24 00:00:00.000                   CT CHEST AND UPPER ABD W
#  10       2012-12-29 00:00:00.000                        XR Chest PA/Lateral
#  11       2012-12-29 00:00:00.000                        XR Chest PA/Lateral
#  12       2012-12-29 00:00:00.000                        XR Chest PA/Lateral
#  13       2013-01-31 00:00:00.000                 CT Chest & Upper Abdomen w
#  14       2013-01-31 00:00:00.000               CT Head & Soft Tissue Neck w
#  15       2013-01-31 00:00:00.000               CT Head & Soft Tissue Neck w
#  16       2013-01-31 00:00:00.000                 CT Chest & Upper Abdomen w
#  17       2012-12-06 00:00:00.000               CT Head & Soft Tissue Neck w
#  18       2012-12-06 00:00:00.000                 CT Chest & Upper Abdomen w
#  19       2012-12-06 00:00:00.000               CT Head & Soft Tissue Neck w
#  20       2012-12-06 00:00:00.000                 CT Chest & Upper Abdomen w
#  21       2012-08-18 00:00:00.000                 CT Chest & Upper Abdomen w
#  22       2012-04-22 00:00:00.000                CT Chest, Abdomen, Pelvis w
#  23       2012-04-22 00:00:00.000                CT Chest, Abdomen, Pelvis w
#  24       2012-09-17 00:00:00.000                        XR Chest PA/Lateral
#  25       2012-11-28 00:00:00.000                 CT Chest & Upper Abdomen w
#  26       2012-11-28 00:00:00.000                 CT Chest & Upper Abdomen w
#  27       2012-05-28 00:00:00.000                   CT CHEST AND UPPER ABD W
#  28       2012-05-28 00:00:00.000                   CT CHEST AND UPPER ABD W
#  29       2012-11-11 00:00:00.000                        XR Chest PA/Lateral
#  ...                          ...                                        ...
#  1275918  2018-02-11 00:00:00.000                                 CT Head wo
#  1275919  2018-02-22 00:00:00.000                      XR Port Chest, 1 View
#  1275920  2018-02-22 00:00:00.000   XR PORT ABD COMP DECUB AND OR ERCT MIN2V
#  1275921  2018-02-11 00:00:00.000                                 CT Head wo
#  1275922  2018-02-22 00:00:00.000                      XR Port Chest, 1 View
#  1275923  2018-02-11 00:00:00.000                CT Upper Abdomen & Pelvis w
#  1275924  2018-02-08 00:00:00.000                   XR Portable Chest, 1View
#  1275925  2018-02-08 00:00:00.000                   XR Portable Chest, 1View
#  1275926  2018-02-22 00:00:00.000   XR PORT ABD COMP DECUB AND OR ERCT MIN2V
#  1275927  2018-03-27 00:00:00.000                        XR Chest PA/Lateral
#  1275928  2018-03-27 00:00:00.000                              CT PE Chest w
#  1275929  2018-03-27 00:00:00.000                              CT PE Chest w
#  1275930  2018-03-27 00:00:00.000                        XR Chest PA/Lateral
#  1275931  2018-08-08 00:00:00.000                CT Upper Abdomen & Pelvis w
#  1275932  2018-08-08 00:00:00.000                        XR Chest PA/Lateral
#  1275933  2018-08-08 00:00:00.000                        XR Chest PA/Lateral
#  1275934  2018-08-08 00:00:00.000                CT Upper Abdomen & Pelvis w
#  1275935  2018-05-09 00:00:00.000                        XR Chest PA/Lateral
#  1275936  2018-05-09 00:00:00.000                        XR Chest PA/Lateral
#  1275937  2018-09-06 00:00:00.000              CT Upper Abdomen & Pelvis WWO
#  1275938  2018-09-06 00:00:00.000              CT Upper Abdomen & Pelvis WWO
#  1275939  2017-12-31 00:00:00.000                                CT Chest wo
#  1275940  2017-12-31 00:00:00.000                                CT Chest wo
#  1275941  2018-10-11 00:00:00.000                CT Upper Abdomen & Pelvis w
#  1275942  2018-10-11 00:00:00.000                CT Upper Abdomen & Pelvis w
#  1275943  2018-10-12 00:00:00.000  XR Abd Complete w Erect & Or Decub min 2v
#  1275944  2018-10-12 00:00:00.000  XR Abd Complete w Erect & Or Decub min 2v
#  1275945  2018-04-21 00:00:00.000                                CT Chest wo
#  1275946  2018-05-08 00:00:00.000                               CT Pelvis wo
#  1275947  2018-05-08 00:00:00.000                               CT Pelvis wo
#
#  [1275948 rows x 5 columns]]

# %%
cohort1_dta_part2.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-97-624d496ef487> in <module>()
# ----> 1 cohort1_dta_part2
#
# NameError: name 'cohort1_dta_part2' is not defined

# %%
frame = pd.DataFrame()
list_ = []

def readin(listoffiles,like):
    for f in listoffiles:
        if f.find(like) == -1:
            print("skipped:",f)
        else:
            print("processed",f)
            df = pd.read_csv(f,index_col=None, header=0,sep="|")
            df.columns = [x.lower() for x in df.columns]
            list_.append(df)
    suffix = ('_patient', '_encounter', '_encounter_provider', '_encounter_social','_dx_info','_radiology')
    for i in range(0,len(list_)):
        print(i)
        tmp1 = pd.DataFrame(list_[i].iloc[:,0])
#         print(tmp1)
        list_[i] = list_[i].iloc[:,1:].add_suffix(suffix[i])
        list_[i] = pd.concat((tmp1,(list_[i])),axis=1)
    frame = reduce(lambda x, y: pd.merge(x, y, on = 'patient_id',how="left"), list_)
    return(frame)

# %% [markdown]
# ### Replace _list with the new filename

# %%
onlyfiles_sorted[1] = join(mypath,"01_PATIENT_COHORT_2_NEW.csv")
onlyfiles_sorted[1]
# Out:
# 'Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_2_NEW.csv'

# %%
onlyfiles_sorted[0:4]
# Out:
# ['Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/02_PATIENT_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/03_ENCOUNTER_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/04_ENCOUNTER_COHORT_2.csv']

# %%
cohort2_dta = readin(onlyfiles_sorted[0:4],"COHORT_2")
# Out:
# skipped: Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_1.csv
# processed Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_2_NEW.csv
# skipped: Z:/FINAL OUTPUT v2/03_ENCOUNTER_COHORT_1.csv
# processed Z:/FINAL OUTPUT v2/04_ENCOUNTER_COHORT_2.csv
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2850: DtypeWarning: Columns (6,13,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-252-91ec4f0a4ca9> in <module>()
# ----> 1 cohort2_dta = readin(onlyfiles_sorted[0:4],"COHORT_2")
#
# <ipython-input-231-1f11588c6850> in readin(listoffiles, like)
#      14 #     return(list_)
#      15 #     frame = pd.concat(list_,join="outer",ignore_index=True)
# ---> 16     frame = reduce(lambda x, y: pd.merge(x, y, on = 'patient_id',how="left"), list_)
#      17     return(frame)
#
# <ipython-input-231-1f11588c6850> in <lambda>(x, y)
#      14 #     return(list_)
#      15 #     frame = pd.concat(list_,join="outer",ignore_index=True)
# ---> 16     frame = reduce(lambda x, y: pd.merge(x, y, on = 'patient_id',how="left"), list_)
#      17     return(frame)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      56                          copy=copy, indicator=indicator,
#      57                          validate=validate)
# ---> 58     return op.get_result()
#      59
#      60
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     594             [(ldata, lindexers), (rdata, rindexers)],
#     595             axes=[llabels.append(rlabels), join_index],
# --> 596             concat_axis=0, copy=self.copy)
#     597
#     598         typ = self.left._constructor
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#    5201         else:
#    5202             b = make_block(
# -> 5203                 concatenate_join_units(join_units, concat_axis, copy=copy),
#    5204                 placement=placement)
#    5205         blocks.append(b)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in concatenate_join_units(join_units, concat_axis, copy)
#    5330     to_concat = [ju.get_reindexed_values(empty_dtype=empty_dtype,
#    5331                                          upcasted_na=upcasted_na)
# -> 5332                  for ju in join_units]
#    5333
#    5334     if len(to_concat) == 1:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in <listcomp>(.0)
#    5330     to_concat = [ju.get_reindexed_values(empty_dtype=empty_dtype,
#    5331                                          upcasted_na=upcasted_na)
# -> 5332                  for ju in join_units]
#    5333
#    5334     if len(to_concat) == 1:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in get_reindexed_values(self, empty_dtype, upcasted_na)
#    5630             for ax, indexer in self.indexers.items():
#    5631                 values = algos.take_nd(values, indexer, axis=ax,
# -> 5632                                        fill_value=fill_value)
#    5633
#    5634         return values
#
# KeyboardInterrupt:

# %%
cohort2_dta.shape
# Out:
# (5695268, 335)

# %%
cohort2_dta.head()
# Out:
#   abstinence_yn adm_date_d admit_source_1 admit_source_2 admit_source_3  \
# 0           NaN        NaN            NaN            NaN            NaN
# 1           NaN        NaN            NaN            NaN            NaN
# 2           NaN        NaN            NaN            NaN            NaN
# 3           NaN        NaN            NaN            NaN            NaN
# 4           NaN        NaN            NaN            NaN            NaN
#
#   admitting_prov_id admitting_provider_department  age_at_last_encounter  \
# 0               NaN                           NaN                   90.0
# 1               NaN                           NaN                   63.0
# 2               NaN                           NaN                   65.0
# 3               NaN                           NaN                   47.0
# 4               NaN                           NaN                   52.0
#
#   alcohol_oz_per_wk alcohol_src_c  ...  tobacco_pak_per_dy tobacco_used_years  \
# 0               NaN           NaN  ...                 NaN                NaN
# 1               NaN           NaN  ...                 NaN                NaN
# 2               NaN           NaN  ...                 NaN                NaN
# 3               NaN           NaN  ...                 NaN                NaN
# 4               NaN           NaN  ...                 NaN                NaN
#
#    tobacco_user unknown_fam_hx_yn visit_status_1 visit_status_2  \
# 0           NaN               NaN            NaN            NaN
# 1           NaN               NaN            NaN            NaN
# 2           NaN               NaN            NaN            NaN
# 3           NaN               NaN            NaN            NaN
# 4           NaN               NaN            NaN            NaN
#
#   visit_status_3 visit_status_4 years_education zip_d
# 0            NaN            NaN             NaN   NaN
# 1            NaN            NaN             NaN   NaN
# 2            NaN            NaN             NaN   NaN
# 3            NaN            NaN             NaN   NaN
# 4            NaN            NaN             NaN   NaN
#
# [5 rows x 335 columns]

# %% [markdown]
# # Write csvs

# %%
cohort1_dta.to_csv(join(mypath,"merged_cohort1.csv"),sep="|")
cohort2_dta.to_csv(join(mypath,"merged_cohort2.csv"),sep="|")

# %% [markdown]
# # Joining to rad notes
#
# Note the links will be messy until we get clarification.
#
# Second string is "encounter_id"

# %%
# extract encounter_id from notes
mypathnotes = "Z:/FINAL OUTPUT v2/NOTES/"
onlyfilesnotes = [join(mypathnotes,f) for f in listdir(mypathnotes) if isfile(join(mypathnotes, f))]
onlyfilesnotes_sorted = sorted(onlyfilesnotes, key=lambda x:(x!="cohort", x))

# cohort 1
notes1 = pd.read_csv(onlyfilesnotes_sorted[0],index_col=None, header=0,sep=",")
notes1.columns = [x.lower() for x in notes1.columns]

# cohort 2
# notes2 = pd.read_csv(onlyfilesnotes_sorted[0],index_col=None, header=0,sep="|")
# notes1.columns = [x.lower() for x in df.columns]

# %%
notes1.head()
# Out:
#    unnamed: 0                                           scantype  \
# 0           0                               XR CHEST PA/LATERAL,
# 1           1                                         CT CHEST W
# 2           2                               XR CHEST PA/LATERAL,
# 3           3                               XR CHEST PA/LATERAL,
# 4           4  These outside images were loaded for compariso...
#
#                   scandate                                           clininfo  \
# 0   2015-06-22**]> 8:24 AM  **NAME<HHH> **AGE<in 50s> years old. Reason: s...
# 1  2015-02-06**]> 12:25 PM        **AGE<in 60s>-year-old male with eye on the
# 2  2015-05-23**]> 10:08 AM  **NAME<FFF> **AGE<in 60s> years old. One month...
# 3  2015-06-24**]> 12:40 PM  **NAME<DDD> **AGE<in 50s> years old. Dyspnea, ...
# 4                      NaN                                                NaN
#
#                                            technique  \
# 0                                XR CHEST PA/LATERAL
# 1  Contrast enhanced chest CT.  120 mL of Omnipaq...
# 2                                XR CHEST PA/LATERAL
# 3                                XR CHEST PA/LATERAL
# 4                                                NaN
#
#                                    comparison  \
# 0      **DATE<[**2015-06-14**]> and previous.
# 1  Outside CXR dated **DATE<[**2015-01-11**]>
# 2                   **DATE<[**2015-05-02**]>.
# 3       **DATE<[**2014-09-03**]> and previous
# 4                                         NaN
#
#                                             findings  \
# 0  Status post right lung biopsies. No significan...
# 1  LUNGS AND PLEURA: Mild subpleural reticulation...
# 2  Elevation of the left hemidiaphragm unchanged....
# 3  Diffuse fine reticular opacities throughout bo...
# 4                                                NaN
#
#                                          impressions  \
# 0  No significant abnormality following multiple ...
# 1  Mild subpleural interstitial fibrosis of undet...
# 2  Severe interstitial abnormality without visibl...
# 3  Diffuse groundglass opacities consistent with ...
# 4                                                NaN
#
#                                              elecsig             patient  \
# 0  **DATE<[**2015-06-22**]> 10:06 AM **NAME<III J...    5253312_70864302
# 1  **DATE<[**2015-02-06**]> 2:26 PM **NAME<CCC DD...    5049178_68355312
# 2  **DATE<[**2015-05-23**]> 10:42 AM [**Doctor Fi...    5861184_69548263
# 3  **DATE<[**2015-06-24**]> 2:22 PM **NAME<EEE FF...    5630079_69208276
# 4     **DATE<[**2018-04-03**]> 8:07 AM Canned Report   8425699_110461983
#
#                                              rawtext
# 0  XR CHEST PA/LATERAL, **DATE<[**2015-06-22**]> ...
# 1  CT CHEST W  **DATE<[**2015-02-06**]> 12:25 PM\...
# 2  XR CHEST PA/LATERAL, **DATE<[**2015-05-23**]> ...
# 3  XR CHEST PA/LATERAL, **DATE<[**2015-06-24**]> ...
# 4  These outside images were loaded for compariso...

# %%
# split 1
notes1[['patient1','patient2']] = notes1['patient'].str.split('_',expand=True)

# split2
# notes2[['patient1','patient2']] = notes2['patient'].str.split('_',expand=True)

# %%
notes1_patient = notes1.patient
notes1_patient.to_csv(join(mypath,"/notes_radiology_edited.csv"),sep="|")

# %% [markdown]
# ### Now join notes for cohort1

# %%
cohort1_dta_notes = pd.merge(cohort1_dta, notes1, on = 'patient_id',how="left")

# %%
cohort1_dta[['patient_id','encounter_id_radiology']]
# Out:
#       patient_id  encounter_id_radiology
# 0          32124                     NaN
# 1          32124                     NaN
# 2          32124                     NaN
# 3          32124                     NaN
# 4          74912                     NaN
# 5          74912                     NaN
# 6          74912                     NaN
# 7          74912                     NaN
# 8          74912                     NaN
# 9          74912                     NaN
# 10         74912                     NaN
# 11         81545                     NaN
# 12         81545                     NaN
# 13         81545                     NaN
# 14         93110                     NaN
# 15         93110                     NaN
# 16         93110                     NaN
# 17         93110                     NaN
# 18        118647                     NaN
# 19        118647                     NaN
# 20        118647                     NaN
# 21        122487                     NaN
# 22        122522                     NaN
# 23        122522                     NaN
# 24        122522                     NaN
# 25        122522                     NaN
# 26        136921                     NaN
# 27        136921                     NaN
# 28        136921                     NaN
# 29        136921                     NaN
# ...          ...                     ...
# 83847    2047068                     NaN
# 83848    2047068                     NaN
# 83849    2047068                     NaN
# 83850    2047068                     NaN
# 83851    2122393                     NaN
# 83852    2122393                     NaN
# 83853    2122393                     NaN
# 83854    2122393                     NaN
# 83855    2122393                     NaN
# 83856    2122393                     NaN
# 83857    2122393                     NaN
# 83858    2122393                     NaN
# 83859    2122393                     NaN
# 83860    2122393                     NaN
# 83861    2122393                     NaN
# 83862    2122393                     NaN
# 83863    2122393                     NaN
# 83864    2122393                     NaN
# 83865    2122393                     NaN
# 83866    2122393                     NaN
# 83867    2122393                     NaN
# 83868    2122393                     NaN
# 83869    2122393                     NaN
# 83870    2122393                     NaN
# 83871    2122393                     NaN
# 83872    2122393                     NaN
# 83873    2122393                     NaN
# 83874    2122393                     NaN
# 83875    2122393                     NaN
# 83876    2122393                     NaN
#
# [83877 rows x 2 columns]

# %%
cohort1_dta[cohort1_dta.encounter_id_radiology.notnull()]
# Out:
# Empty DataFrame
# Columns: [patient_id, age_at_last_encounter_patient, gender_patient, race_patient, ethnicity_patient, date_of_death_d_patient, encounter_id_encounter, enc_eio_encounter, visit_status_1_encounter, visit_status_2_encounter, visit_status_3_encounter, visit_status_4_encounter, adm_date_d_encounter, disc_date_d_encounter, start_date_d_encounter, end_date_d_encounter, admit_source_1_encounter, admit_source_2_encounter, admit_source_3_encounter, disch_disp_1_encounter, disch_disp_2_encounter, disch_disp_3_encounter, zip_d_encounter, enc_fin_class_encounter, encounter_id_encounter_provider, admitting_prov_id_encounter_provider, admitting_provider_department_encounter_provider, attnd_prov_id_encounter_provider, attending_department_encounter_provider, referring_prov_id_encounter_provider, referring_department_encounter_provider, contact_date_off_encounter_social, is_tobacco_user_encounter_social, tobacco_pak_per_dy_encounter_social, tobacco_used_years_encounter_social, tobacco_comment_encounter_social, smoking_quit_date_off_encounter_social, cigarettes_yn_encounter_social, pipes_yn_encounter_social, cigars_yn_encounter_social, snuff_yn_encounter_social, chew_yn_encounter_social, is_alcohol_user_encounter_social, alcohol_oz_per_wk_encounter_social, is_ill_drug_user_encounter_social, iv_drug_user_yn_encounter_social, illicit_drug_freq_encounter_social, is_sexually_actv_encounter_social, female_partner_yn_encounter_social, male_partner_yn_encounter_social, condom_yn_encounter_social, pill_yn_encounter_social, diaphragm_yn_encounter_social, iud_yn_encounter_social, surgical_yn_encounter_social, spermicide_yn_encounter_social, implant_yn_encounter_social, rhythm_yn_encounter_social, injection_yn_encounter_social, sponge_yn_encounter_social, inserts_yn_encounter_social, abstinence_yn_encounter_social, years_education_encounter_social, tob_src_c_encounter_social, alcohol_src_c_encounter_social, sex_src_c_encounter_social, alcohol_use_c_encounter_social, ill_drug_user_c_encounter_social, sexually_active_c_encounter_social, tobacco_user_encounter_social, smokeless_tob_use_c_encounter_social, smokeless_quit_date_off_encounter_social, smoking_tob_use_encounter_social, unknown_fam_hx_yn_encounter_social, smoking_start_date_off_encounter_social, encounter_id_dx_info, dx_1_dx_info, dx_desc_1_dx_info, dx1_rank_dx_info, dx_2_dx_info, dx_desc_2_dx_info, dx2_rank_dx_info, dx_3_dx_info, dx_desc_3_dx_info, dx3_rank_dx_info, dx_4_dx_info, dx_desc_4_dx_info, dx4_rank_dx_info, dx_5_dx_info, dx_desc_5_dx_info, dx5_rank_dx_info, dx_6_dx_info, dx_desc_6_dx_info, dx6_rank_dx_info, dx_7_dx_info, dx_desc_7_dx_info, dx7_rank_dx_info, dx_8_dx_info, dx_desc_8_dx_info, dx8_rank_dx_info, ...]
# Index: []
#
# [0 rows x 119 columns]
