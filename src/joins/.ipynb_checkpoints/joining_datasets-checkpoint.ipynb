# %% [markdown]
# # JOINS
#
# This jupyter is to join the datasets with their
# one to many notes files.

# %%
import string
import bz2
from os import listdir
from os.path import isfile, join
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import datetime
import nltk.corpus  
import time
import math
import re
import spacy
from functools import reduce
from nltk.text import Text
from nltk.corpus import stopwords
from itertools import combinations
from textblob import TextBlob
from textblob.sentiments import NaiveBayesAnalyzer
from textblob import TextBlob
from nltk.stem.wordnet import WordNetLemmatizer
# from keras.preprocessing import text, sequence
# from keras.utils import to_categorical
# from keras.layers import Bidirectional, GlobalMaxPool1D,GlobalMaxPool2D, GlobalMaxPool3D,Conv1D, Dense, Input, LSTM, Embedding, Dropout, Activation
# from keras.models import Model, Sequential
# from keras.callbacks import EarlyStopping, ModelCheckpoint
# %matplotlib inline
plt.style.use('fivethirtyeight')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\t.cri.kcheung\\capstone_nlp\\src\\joins'

# %%
# get all files in subfolder
mypath = "Z:/FINAL OUTPUT v2/"
onlyfiles = [join(mypath,f) for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
onlyfiles
# Out:
# ['Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_1_MOVEDFROMCOHORT2.csv',
#  'Z:/FINAL OUTPUT v2/07_ENCOUNTER_SOCIAL_HX_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/09_DX_INFO_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/merged_cohort1.csv',
#  'Z:/FINAL OUTPUT v2/05_ENCOUNTER_PROVIDER_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/04_ENCOUNTER_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/06_ENCOUNTER_PROVIDER_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/02_PATIENT_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/merged_cohort2.csv',
#  'Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_2_NEW.csv',
#  'Z:/FINAL OUTPUT v2/03_ENCOUNTER_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/11_COHORT_1_RADIOLOGY.csv',
#  'Z:/FINAL OUTPUT v2/08_ENCOUNTER_SOCIAL_HX_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/10_DX_INFO_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/merged_cohort2_sampled.csv',
#  'Z:/FINAL OUTPUT v2/12_COHORT_2_RADIOLOGY.csv',
#  'Z:/FINAL OUTPUT v2/merged_movedfromcohort1.csv']

# %%
onlyfiles
# Out:
# ['Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_1_MOVEDFROMCOHORT2.csv',
#  'Z:/FINAL OUTPUT v2/07_ENCOUNTER_SOCIAL_HX_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/09_DX_INFO_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/merged_cohort1.csv',
#  'Z:/FINAL OUTPUT v2/05_ENCOUNTER_PROVIDER_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/04_ENCOUNTER_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/06_ENCOUNTER_PROVIDER_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/02_PATIENT_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/merged_cohort2.csv',
#  'Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_2_NEW.csv',
#  'Z:/FINAL OUTPUT v2/03_ENCOUNTER_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/11_COHORT_1_RADIOLOGY.csv',
#  'Z:/FINAL OUTPUT v2/08_ENCOUNTER_SOCIAL_HX_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/10_DX_INFO_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/12_COHORT_2_RADIOLOGY.csv']

# %% [markdown]
# # Modular

# %%
onlyfiles_sorted = sorted(onlyfiles, key=lambda x:(x!="PATIENT_COHORT", x))

# %%
onlyfiles_sorted_edit = list( onlyfiles_sorted[i] for i in [0,4,6,8,10,12] )
onlyfiles_sorted_edit
# Out:
# ['Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/03_ENCOUNTER_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/05_ENCOUNTER_PROVIDER_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/07_ENCOUNTER_SOCIAL_HX_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/09_DX_INFO_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/11_COHORT_1_RADIOLOGY.csv']

# %% [markdown]
# ### Prior to loading in lets check for j84 in part 2

# %%
onlyfiles_sorted[11]
# Out:
# 'Z:/FINAL OUTPUT v2/10_DX_INFO_COHORT_2.csv'

# %%
cohort2_icd_check = pd.read_csv(onlyfiles_sorted[11],sep="|")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (98,110,113,116,117,119,120,122,123,125,126,128,129,131,132,134,135,137,138,140,141,143,144,146,147,149,150,152,153,155,156,158,159,161,162,164,165,167,168,170,171,173,174,176,177,179,180,182,183,185,186,188,189,191,192,194,195,197,198,200,201,203,204,206,207,209,210,212,213,215,216,218,219,221,222,224,225,227,228,230,231,233,234,236,237,239,240,242,243,245,246,248,249,251,252,254,255,257,258) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# get list of columns with dx
dx_cols = [col for col in cohort2_icd_check.columns if 'dx_' in col]
dx_cols[0]
# Out:
# 'dx_1'

# %%
# all icd codes list
icd_codes_list = ['495','4951','4952','4953','4954','4955','4956','4957','4958','4959','496','515','517','5171','5172','5173','5178','516','5160','5161','5162','5163','51630','51631','51632','51633','51634','51635','51636','51637','5164','5165','5166','51661','51662','51663','51664','51669','5168','5169','J670','J671','J672','J673','J674','J675','J676','J677','J678','J679','J6710','J8410','J8489','J17','M3481','J99','J8401','J8402','J8403','J84111','J84112','J84113','J84114','J84115','J84116','J84117','J8481','J8482','J8483','J84841','J84842','J84843','J84844','J84845','J84848','J8409','J849']
pattern = '|'.join(icd_codes_list)

# %%
# extract all
icd_subset = []

for col in dx_cols:
#     print(col)
    tmpdf = cohort2_icd_check[cohort2_icd_check[col].str.contains(pattern,na=False)]
    icd_subset.append(tmpdf)
# print(icd_subset)

# %%
icd_subset_df = icd_subset[0]

# %%
len(np.unique(icd_subset_df.PATIENT_ID))
# Out:
# 2243

# %% [markdown]
# # Now i have all the patients with the relevant icd codes. Around 2k unique of them.
#
# We need to extract all of the relevant records into their own df. Let's tweak the merging into just those of which that are in the lsit of patients.

# %%
onlyfiles_sorted
# Out:
# ['Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_1_MOVEDFROMCOHORT2.csv',
#  'Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_2_NEW.csv',
#  'Z:/FINAL OUTPUT v2/02_PATIENT_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/03_ENCOUNTER_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/04_ENCOUNTER_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/05_ENCOUNTER_PROVIDER_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/06_ENCOUNTER_PROVIDER_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/07_ENCOUNTER_SOCIAL_HX_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/08_ENCOUNTER_SOCIAL_HX_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/09_DX_INFO_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/10_DX_INFO_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/11_COHORT_1_RADIOLOGY.csv',
#  'Z:/FINAL OUTPUT v2/12_COHORT_2_RADIOLOGY.csv',
#  'Z:/FINAL OUTPUT v2/merged_cohort1.csv',
#  'Z:/FINAL OUTPUT v2/merged_cohort2.csv']

# %%
cohort2move = pd.read_csv(onlyfiles_sorted[3],sep="|")
cohort2move.head()
# Out:
#    PATIENT_ID  AGE_AT_LAST_ENCOUNTER gender                    race  \
# 0          49                   79.0      M                   White
# 1          99                   86.0      F                   White
# 2         104                   84.0      M                   White
# 3         114                   66.0      F                   White
# 4         118                   92.0      F  Black/African-American
#
#                 ETHNICITY DATE_OF_DEATH_D
# 0  Not Hispanic or Latino             NaN
# 1  Not Hispanic or Latino             NaN
# 2  Not Hispanic or Latino             NaN
# 3  Not Hispanic or Latino             NaN
# 4  Not Hispanic or Latino             NaN

# %%
cohort2movedf = cohort2move[cohort2move.PATIENT_ID.isin(icd_subset_df.PATIENT_ID)]

# %%
cohort2movedf.to_csv(join(mypath,"01_PATIENT_COHORT_1_MOVEDFROMCOHORT2.csv"),sep="|",index=False)

# %% [markdown]
# ### Prior to loading in the second cohort let's randomly sample in 10k rows

# %%
cohort2move.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-a555ebd4691e> in <module>()
# ----> 1 cohort2move.head()
#
# NameError: name 'cohort2move' is not defined

# %%
cohort2removeddf = cohort2move[~cohort2move.PATIENT_ID.isin(icd_subset_df.PATIENT_ID)]

# %%
cohort2sampdf = cohort2removeddf.sample(n=30000,random_state=10,replace=False)
cohort2sampdf.shape
# Out:
# (30000, 6)

# %%
cohort2sampdf.to_csv(join(mypath,"01_PATIENT_COHORT_2_NEW.csv"),sep="|",index=False)

# %%
del cohort2move, cohort2_icd_check,cohort2move
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-f07d4428dcd0> in <module>()
# ----> 1 del cohort2move, cohort2_icd_check,cohort2move
#
# NameError: name 'cohort2_icd_check' is not defined

# %% [markdown]
# # Next step we need to create a join list with just the ids in moved from cohort2 set
#
# Then we can merge them into a consolidated cohort1

# %%
onlyfiles2 = [join(mypath,f) for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
onlyfiles2
# Out:
# ['Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_1_MOVEDFROMCOHORT2.csv',
#  'Z:/FINAL OUTPUT v2/07_ENCOUNTER_SOCIAL_HX_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/09_DX_INFO_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/merged_cohort1.csv',
#  'Z:/FINAL OUTPUT v2/05_ENCOUNTER_PROVIDER_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/04_ENCOUNTER_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/06_ENCOUNTER_PROVIDER_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/02_PATIENT_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/merged_cohort2.csv',
#  'Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_2_NEW.csv',
#  'Z:/FINAL OUTPUT v2/03_ENCOUNTER_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/11_COHORT_1_RADIOLOGY.csv',
#  'Z:/FINAL OUTPUT v2/08_ENCOUNTER_SOCIAL_HX_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/10_DX_INFO_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/12_COHORT_2_RADIOLOGY.csv']

# %%
onlyfiles2edit = list( onlyfiles2[i] for i in [0, 6, 7, 13,14,15] )
# onlyfiles2edit = list( onlyfiles2[i] for i in [0,15] )

# %%
onlyfiles2edit
# Out:
# ['Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_1_MOVEDFROMCOHORT2.csv',
#  'Z:/FINAL OUTPUT v2/04_ENCOUNTER_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/06_ENCOUNTER_PROVIDER_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/08_ENCOUNTER_SOCIAL_HX_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/10_DX_INFO_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/12_COHORT_2_RADIOLOGY.csv']

# %%
# test
def test(listoffiles,like,patientids):
    for f in listoffiles:
        if f.find(like) == -1:
            print("skipped:",f)
        else:
            print("added to list_",f)
            df = pd.read_csv(f,index_col=None, header=0,sep="|")
            df.columns = [x.lower() for x in df.columns]
            df = df[df['patient_id'].isin(patientids)]
            return(df)

# %%
patientlist = [114]

# %%
test(onlyfiles2edit,"COHORT",patientlist)
# Out:
# added to list_ Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_1_MOVEDFROMCOHORT2.csv
#    patient_id  age_at_last_encounter gender   race               ethnicity  \
# 0         114                   66.0      F  White  Not Hispanic or Latino
#
#   date_of_death_d
# 0             NaN

# %% [markdown]
# ### Edited fx
#
# For mem purposes let's amend each read in to be just where it matches the patient id string

# %%
patientlist = np.unique(icd_subset_df['PATIENT_ID'])
patientlist[0:5]
# Out:
# array([ 114,  431,  672, 1408, 1549], dtype=int64)

# %%
frame = pd.DataFrame()
list_ = []

def readin_select(listoffiles,like,patientids):
    for f in listoffiles:
        if f.find(like) == -1:
            print("skipped:",f)
        else:
            print("added to list_",f)
            df = pd.read_csv(f,index_col=None, header=0,sep="|")
            df.columns = [x.lower() for x in df.columns]
            df = df[df['patient_id'].isin(patientlist)]
            list_.append(df)

# %%
readin_select(onlyfiles2edit,"COHORT",patientlist)
# Out:
# added to list_ Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_1_MOVEDFROMCOHORT2.csv
# added to list_ Z:/FINAL OUTPUT v2/04_ENCOUNTER_COHORT_2.csv
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2856: DtypeWarning: Columns (6,13,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# added to list_ Z:/FINAL OUTPUT v2/06_ENCOUNTER_PROVIDER_COHORT_2.csv
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2856: DtypeWarning: Columns (2,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# added to list_ Z:/FINAL OUTPUT v2/08_ENCOUNTER_SOCIAL_HX_COHORT_2.csv
# added to list_ Z:/FINAL OUTPUT v2/10_DX_INFO_COHORT_2.csv
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2856: DtypeWarning: Columns (98,110,113,116,117,119,120,122,123,125,126,128,129,131,132,134,135,137,138,140,141,143,144,146,147,149,150,152,153,155,156,158,159,161,162,164,165,167,168,170,171,173,174,176,177,179,180,182,183,185,186,188,189,191,192,194,195,197,198,200,201,203,204,206,207,209,210,212,213,215,216,218,219,221,222,224,225,227,228,230,231,233,234,236,237,239,240,242,243,245,246,248,249,251,252,254,255,257,258) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# added to list_ Z:/FINAL OUTPUT v2/12_COHORT_2_RADIOLOGY.csv

# %%
list_[0].iloc[1:5,:]
# Out:
#    patient_id  age_at_last_encounter gender                    race  \
# 1         431                   88.0      F  Black/African-American
# 2         672                   80.0      M    Asian/Mideast Indian
# 3        1408                   84.0      F  Black/African-American
# 4        1549                   80.0      F  Black/African-American
#
#                 ethnicity date_of_death_d
# 1  Not Hispanic or Latino             NaN
# 2  Not Hispanic or Latino             NaN
# 3  Not Hispanic or Latino             NaN
# 4  Not Hispanic or Latino             NaN

# %%
list_[5].iloc[1:5,:]
# Out:
#     patient_id  encounter_id  order_proc_id_deid        ordering_date_off  \
# 26     1766157       3759747             1002716  2012-11-28 00:00:00.000
# 53     1380083       3938864              800327  2012-10-24 00:00:00.000
# 62     1366083       3939557              737500  2013-06-21 00:00:00.000
# 63     1366083       3939557             1260359  2013-06-21 00:00:00.000
#
#                       exam_type
# 26   CT Chest & Upper Abdomen w
# 53  CT Upper Abdomen & Pelvis w
# 62   CT Chest & Upper Abdomen w
# 63   CT Chest & Upper Abdomen w

# %%
len(list_[5])
# Out:
# 59663

# %%
# spot check on patient ids 
list_[5][list_[5].patient_id==1408]
list_[0][list_[0].patient_id==1380083]
# Out:
#      patient_id  age_at_last_encounter gender                    race  \
# 879     1380083                   65.0      F  Black/African-American
#
#                   ethnicity          date_of_death_d
# 879  Not Hispanic or Latino  2014-10-13 00:00:00.000

# %% [markdown]
# # Correctly appending in function
#
# Let's now see if we can use dask to improve the join functionality of the other datasets given memory issues.

# %%
import dask.dataframe as dd
from dask.diagnostics import ProgressBar
pbar = ProgressBar()
pbar.register()

df1 = list_[0]
df2 = list_[5]

# %%
print(df1.head())
print(len(df1))
# Out:
#    patient_id  age_at_last_encounter gender                    race  \
# 0         114                   66.0      F                   White
# 1         431                   88.0      F  Black/African-American
# 2         672                   80.0      M    Asian/Mideast Indian
# 3        1408                   84.0      F  Black/African-American
# 4        1549                   80.0      F  Black/African-American
#
#                 ethnicity date_of_death_d
# 0  Not Hispanic or Latino             NaN
# 1  Not Hispanic or Latino             NaN
# 2  Not Hispanic or Latino             NaN
# 3  Not Hispanic or Latino             NaN
# 4  Not Hispanic or Latino             NaN
# 2243

# %%
print(df2.head())
print(len(df2))
# Out:
#     patient_id  encounter_id  order_proc_id_deid        ordering_date_off  \
# 25     1766157       3759747              706804  2012-11-28 00:00:00.000
# 26     1766157       3759747             1002716  2012-11-28 00:00:00.000
# 53     1380083       3938864              800327  2012-10-24 00:00:00.000
# 62     1366083       3939557              737500  2013-06-21 00:00:00.000
# 63     1366083       3939557             1260359  2013-06-21 00:00:00.000
#
#                       exam_type
# 25   CT Chest & Upper Abdomen w
# 26   CT Chest & Upper Abdomen w
# 53  CT Upper Abdomen & Pelvis w
# 62   CT Chest & Upper Abdomen w
# 63   CT Chest & Upper Abdomen w
# 59663

# %%
mergetest = dd.merge(df1, df2, how='outer', on=['patient_id'])

# %%
mergetest
# Out:
#        patient_id  age_at_last_encounter gender                    race  \
# 0             114                   66.0      F                   White
# 1             114                   66.0      F                   White
# 2             114                   66.0      F                   White
# 3             114                   66.0      F                   White
# 4             114                   66.0      F                   White
# 5             114                   66.0      F                   White
# 6             114                   66.0      F                   White
# 7             114                   66.0      F                   White
# 8             114                   66.0      F                   White
# 9             114                   66.0      F                   White
# 10            114                   66.0      F                   White
# 11            114                   66.0      F                   White
# 12            114                   66.0      F                   White
# 13            114                   66.0      F                   White
# 14            114                   66.0      F                   White
# 15            114                   66.0      F                   White
# 16            114                   66.0      F                   White
# 17            114                   66.0      F                   White
# 18            114                   66.0      F                   White
# 19            114                   66.0      F                   White
# 20            114                   66.0      F                   White
# 21            114                   66.0      F                   White
# 22            114                   66.0      F                   White
# 23            114                   66.0      F                   White
# 24            114                   66.0      F                   White
# 25            114                   66.0      F                   White
# 26            114                   66.0      F                   White
# 27            114                   66.0      F                   White
# 28            114                   66.0      F                   White
# 29            114                   66.0      F                   White
# ...           ...                    ...    ...                     ...
# 59633     2740460                   40.0      M                   White
# 59634     2740460                   40.0      M                   White
# 59635     2740460                   40.0      M                   White
# 59636     2740460                   40.0      M                   White
# 59637     2740460                   40.0      M                   White
# 59638     2740460                   40.0      M                   White
# 59639     2740460                   40.0      M                   White
# 59640     2740460                   40.0      M                   White
# 59641     2740460                   40.0      M                   White
# 59642     2740460                   40.0      M                   White
# 59643     2779581                   74.0      M                   White
# 59644     2779581                   74.0      M                   White
# 59645     2779581                   74.0      M                   White
# 59646     2849686                   56.0      M  Black/African-American
# 59647     2849686                   56.0      M  Black/African-American
# 59648     2849686                   56.0      M  Black/African-American
# 59649     2959602                   64.0      M  Black/African-American
# 59650     2959602                   64.0      M  Black/African-American
# 59651     2959602                   64.0      M  Black/African-American
# 59652     2959602                   64.0      M  Black/African-American
# 59653     2959602                   64.0      M  Black/African-American
# 59654     2959602                   64.0      M  Black/African-American
# 59655     2959602                   64.0      M  Black/African-American
# 59656     2959602                   64.0      M  Black/African-American
# 59657     2959602                   64.0      M  Black/African-American
# 59658     2959602                   64.0      M  Black/African-American
# 59659     2959602                   64.0      M  Black/African-American
# 59660     2959602                   64.0      M  Black/African-American
# 59661     2959602                   64.0      M  Black/African-American
# 59662     2959602                   64.0      M  Black/African-American
#
#                     ethnicity          date_of_death_d  encounter_id  \
# 0      Not Hispanic or Latino                      NaN       4645531
# 1      Not Hispanic or Latino                      NaN       5066736
# 2      Not Hispanic or Latino                      NaN       5066736
# 3      Not Hispanic or Latino                      NaN       5097355
# 4      Not Hispanic or Latino                      NaN       6214618
# 5      Not Hispanic or Latino                      NaN       6221749
# 6      Not Hispanic or Latino                      NaN       6221749
# 7      Not Hispanic or Latino                      NaN       6265020
# 8      Not Hispanic or Latino                      NaN       6265020
# 9      Not Hispanic or Latino                      NaN       6747726
# 10     Not Hispanic or Latino                      NaN       6747726
# 11     Not Hispanic or Latino                      NaN       7160379
# 12     Not Hispanic or Latino                      NaN       8413485
# 13     Not Hispanic or Latino                      NaN       8413485
# 14     Not Hispanic or Latino                      NaN       9235183
# 15     Not Hispanic or Latino                      NaN       9494644
# 16     Not Hispanic or Latino                      NaN       9495002
# 17     Not Hispanic or Latino                      NaN       9495002
# 18     Not Hispanic or Latino                      NaN       9495002
# 19     Not Hispanic or Latino                      NaN       9495002
# 20     Not Hispanic or Latino                      NaN       9495002
# 21     Not Hispanic or Latino                      NaN       9495002
# 22     Not Hispanic or Latino                      NaN       9495002
# 23     Not Hispanic or Latino                      NaN       9495002
# 24     Not Hispanic or Latino                      NaN       9495002
# 25     Not Hispanic or Latino                      NaN       9495002
# 26     Not Hispanic or Latino                      NaN       9495002
# 27     Not Hispanic or Latino                      NaN       9495002
# 28     Not Hispanic or Latino                      NaN       9495002
# 29     Not Hispanic or Latino                      NaN       9495002
# ...                       ...                      ...           ...
# 59633  Not Hispanic or Latino                      NaN      11657247
# 59634  Not Hispanic or Latino                      NaN      12529024
# 59635  Not Hispanic or Latino                      NaN      12529024
# 59636  Not Hispanic or Latino                      NaN      12584673
# 59637  Not Hispanic or Latino                      NaN      12584673
# 59638  Not Hispanic or Latino                      NaN      12584673
# 59639  Not Hispanic or Latino                      NaN      12584673
# 59640  Not Hispanic or Latino                      NaN      12584673
# 59641  Not Hispanic or Latino                      NaN      12584673
# 59642  Not Hispanic or Latino                      NaN      12584673
# 59643  Not Hispanic or Latino                      NaN      12521405
# 59644  Not Hispanic or Latino                      NaN      12521405
# 59645  Not Hispanic or Latino                      NaN      12580704
# 59646  Not Hispanic or Latino                      NaN      12234386
# 59647  Not Hispanic or Latino                      NaN      12234386
# 59648  Not Hispanic or Latino                      NaN      12234386
# 59649  Not Hispanic or Latino  2018-12-08 00:00:00.000      12269769
# 59650  Not Hispanic or Latino  2018-12-08 00:00:00.000      12269769
# 59651  Not Hispanic or Latino  2018-12-08 00:00:00.000      12269769
# 59652  Not Hispanic or Latino  2018-12-08 00:00:00.000      12269769
# 59653  Not Hispanic or Latino  2018-12-08 00:00:00.000      12269769
# 59654  Not Hispanic or Latino  2018-12-08 00:00:00.000      12269769
# 59655  Not Hispanic or Latino  2018-12-08 00:00:00.000      12269769
# 59656  Not Hispanic or Latino  2018-12-08 00:00:00.000      12269769
# 59657  Not Hispanic or Latino  2018-12-08 00:00:00.000      12269769
# 59658  Not Hispanic or Latino  2018-12-08 00:00:00.000      12269769
# 59659  Not Hispanic or Latino  2018-12-08 00:00:00.000      12345049
# 59660  Not Hispanic or Latino  2018-12-08 00:00:00.000      12345049
# 59661  Not Hispanic or Latino  2018-12-08 00:00:00.000      12345049
# 59662  Not Hispanic or Latino  2018-12-08 00:00:00.000      12345049
#
#        order_proc_id_deid        ordering_date_off  \
# 0                  856883  2013-08-22 00:00:00.000
# 1                  685083  2013-08-22 00:00:00.000
# 2                  719735  2013-08-22 00:00:00.000
# 3                  973439  2014-01-11 00:00:00.000
# 4                  852596  2014-06-22 00:00:00.000
# 5                  691513  2014-12-06 00:00:00.000
# 6                  993450  2014-12-06 00:00:00.000
# 7                  597997  2014-01-11 00:00:00.000
# 8                 1028470  2014-01-11 00:00:00.000
# 9                  884699  2014-06-28 00:00:00.000
# 10                1280256  2014-06-28 00:00:00.000
# 11                1363180  2014-12-06 00:00:00.000
# 12                 351492  2016-08-27 00:00:00.000
# 13                1445308  2016-08-27 00:00:00.000
# 14                1066104  2017-04-24 00:00:00.000
# 15                 354743  2017-09-01 00:00:00.000
# 16                 518948  2017-07-20 00:00:00.000
# 17                 519309  2017-07-20 00:00:00.000
# 18                 615980  2017-07-12 00:00:00.000
# 19                 630992  2017-06-29 00:00:00.000
# 20                 640493  2017-07-07 00:00:00.000
# 21                 652605  2017-07-12 00:00:00.000
# 22                 732678  2017-07-05 00:00:00.000
# 23                 898546  2017-07-03 00:00:00.000
# 24                 900467  2017-06-29 00:00:00.000
# 25                 929338  2017-07-13 00:00:00.000
# 26                 945319  2017-07-03 00:00:00.000
# 27                 981963  2017-07-16 00:00:00.000
# 28                1009364  2017-07-13 00:00:00.000
# 29                1025343  2017-07-20 00:00:00.000
# ...                   ...                      ...
# 59633             1238113  2018-07-14 00:00:00.000
# 59634             1365030  2018-09-09 00:00:00.000
# 59635             1390748  2018-09-09 00:00:00.000
# 59636              213630  2018-11-09 00:00:00.000
# 59637              281783  2018-10-31 00:00:00.000
# 59638              380540  2018-11-02 00:00:00.000
# 59639              566268  2018-11-02 00:00:00.000
# 59640              783714  2018-10-31 00:00:00.000
# 59641             1018977  2018-10-31 00:00:00.000
# 59642             1224385  2018-10-31 00:00:00.000
# 59643              482014  2017-12-07 00:00:00.000
# 59644              933730  2017-12-07 00:00:00.000
# 59645             1355835  2017-12-02 00:00:00.000
# 59646              724082  2018-09-09 00:00:00.000
# 59647              782976  2018-09-09 00:00:00.000
# 59648             1288252  2018-09-09 00:00:00.000
# 59649              583492  2018-10-17 00:00:00.000
# 59650              704238  2018-10-17 00:00:00.000
# 59651              775072  2018-10-16 00:00:00.000
# 59652              848263  2018-10-16 00:00:00.000
# 59653             1009092  2018-10-16 00:00:00.000
# 59654             1075162  2018-10-16 00:00:00.000
# 59655             1165291  2018-10-16 00:00:00.000
# 59656             1314416  2018-10-14 00:00:00.000
# 59657             1315519  2018-10-14 00:00:00.000
# 59658             1349234  2018-10-16 00:00:00.000
# 59659               65973  2018-11-15 00:00:00.000
# 59660              561872  2018-11-16 00:00:00.000
# 59661              985122  2018-11-15 00:00:00.000
# 59662             1002284  2018-11-16 00:00:00.000
#
#                                    exam_type
# 0                        XR Chest PA/Lateral
# 1                        XR Chest PA/Lateral
# 2                        XR Chest PA/Lateral
# 3                        XR Chest PA/Lateral
# 4                                CT Chest wo
# 5                        XR Chest PA/Lateral
# 6                        XR Chest PA/Lateral
# 7                        XR Chest PA/Lateral
# 8                        XR Chest PA/Lateral
# 9                                CT Chest wo
# 10                               CT Chest wo
# 11                       XR Chest PA/Lateral
# 12          CT Angio Upper Extremity wwo, Lt
# 13                        CT Angio Chest wwo
# 14     CT Chest Low Dose Cancer Screening WO
# 15                               CT Chest wo
# 16                 XR Portable Chest, 1 View
# 17                     XR Port Chest, 1 View
# 18                     XR Port Chest, 1 View
# 19                             CT PE Chest w
# 20                     XR Port Chest, 1 View
# 21                     XR Port Chest, 1 View
# 22                     XR Port Chest, 1 View
# 23                     XR Port Chest, 1 View
# 24                             CT PE Chest w
# 25                               CT Chest wo
# 26                     XR Port Chest, 1 View
# 27                     XR Port Chest, 1 View
# 28                               CT Chest wo
# 29                 XR Portable Chest, 1 View
# ...                                      ...
# 59633                   IOE COM CT ANG CHEST
# 59634                            CT Chest wo
# 59635                            CT Chest wo
# 59636                            CT Chest wo
# 59637               XR Portable Chest, 1View
# 59638            CT Upper Abdomen & Pelvis w
# 59639            CT Upper Abdomen & Pelvis w
# 59640                    XR Chest PA/Lateral
# 59641                    XR Chest PA/Lateral
# 59642               XR Portable Chest, 1View
# 59643                            CT Chest wo
# 59644                            CT Chest wo
# 59645                            CT Chest wo
# 59646                    XR Chest PA/Lateral
# 59647                    XR Chest PA/Lateral
# 59648                    XR Chest PA/Lateral
# 59649                            CT Chest wo
# 59650                            CT Chest wo
# 59651                       IOE COM CT CHEST
# 59652                       IOE COM XR CHEST
# 59653                   IOE COM CT ANG CHEST
# 59654                       IOE COM CT CHEST
# 59655                   IOE COM CT ANG CHEST
# 59656                  XR Port Chest, 1 View
# 59657                  XR Port Chest, 1 View
# 59658                       IOE COM XR CHEST
# 59659                    XR Chest PA/Lateral
# 59660                            CT Chest wo
# 59661                    XR Chest PA/Lateral
# 59662                            CT Chest wo
#
# [59663 rows x 10 columns]

# %% [markdown]
# Let's redo the function now with the dd read in and merge.

# %%
frame = pd.DataFrame()
list_ = []

def readin_select_full(listoffiles,like,patientids):
    for f in listoffiles:
        if f.find(like) == -1:
            print("skipped:",f)
        else:
            print("added to list_",f)
            df = pd.read_csv(f,index_col=None, header=0,sep="|")
            df.columns = [x.lower() for x in df.columns]
            df = df[df['patient_id'].isin(patientlist)].dropna(axis='columns',how='all')
            list_.append(df)
#     suffix = ('_patient', '_encounter', '_encounter_provider', '_encounter_social','_dx_info','_radiology')
    suffix = ('_patient','_radiology')
    for i in range(0,len(list_)):
        print("iteration number",i)
        tmp1 = pd.DataFrame(list_[i].iloc[:,0])
        print("suffix : ",suffix[i])
        list_[i] = list_[i].iloc[:,1:].add_suffix(suffix[i])
        list_[i] = pd.concat((tmp1,(list_[i])),axis=1)
#     frame = reduce(lambda x, y: pd.merge(x, y, on = 'patient_id',how="left"), list_)
    frame = reduce(lambda x, y: dd.merge(x, y, on = ['patient_id'],how="left"), list_)
    print(len(frame))
    return(frame)

# %%
onlyfiles3edit = list( onlyfiles2[i] for i in [0,15] )
onlyfiles3edit
# Out:
# ['Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_1_MOVEDFROMCOHORT2.csv',
#  'Z:/FINAL OUTPUT v2/12_COHORT_2_RADIOLOGY.csv']

# %%
readin_select_full(onlyfiles3edit,"COHORT",patientlist)
# Out:
# added to list_ Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_1_MOVEDFROMCOHORT2.csv
# added to list_ Z:/FINAL OUTPUT v2/12_COHORT_2_RADIOLOGY.csv
# iteration number 0
# suffix :  _patient
# iteration number 1
# suffix :  _radiology
# 59663
#        patient_id  age_at_last_encounter_patient gender_patient  \
# 0             114                           66.0              F
# 1             114                           66.0              F
# 2             114                           66.0              F
# 3             114                           66.0              F
# 4             114                           66.0              F
# 5             114                           66.0              F
# 6             114                           66.0              F
# 7             114                           66.0              F
# 8             114                           66.0              F
# 9             114                           66.0              F
# 10            114                           66.0              F
# 11            114                           66.0              F
# 12            114                           66.0              F
# 13            114                           66.0              F
# 14            114                           66.0              F
# 15            114                           66.0              F
# 16            114                           66.0              F
# 17            114                           66.0              F
# 18            114                           66.0              F
# 19            114                           66.0              F
# 20            114                           66.0              F
# 21            114                           66.0              F
# 22            114                           66.0              F
# 23            114                           66.0              F
# 24            114                           66.0              F
# 25            114                           66.0              F
# 26            114                           66.0              F
# 27            114                           66.0              F
# 28            114                           66.0              F
# 29            114                           66.0              F
# ...           ...                            ...            ...
# 59633     2740460                           40.0              M
# 59634     2740460                           40.0              M
# 59635     2740460                           40.0              M
# 59636     2740460                           40.0              M
# 59637     2740460                           40.0              M
# 59638     2740460                           40.0              M
# 59639     2740460                           40.0              M
# 59640     2740460                           40.0              M
# 59641     2740460                           40.0              M
# 59642     2740460                           40.0              M
# 59643     2779581                           74.0              M
# 59644     2779581                           74.0              M
# 59645     2779581                           74.0              M
# 59646     2849686                           56.0              M
# 59647     2849686                           56.0              M
# 59648     2849686                           56.0              M
# 59649     2959602                           64.0              M
# 59650     2959602                           64.0              M
# 59651     2959602                           64.0              M
# 59652     2959602                           64.0              M
# 59653     2959602                           64.0              M
# 59654     2959602                           64.0              M
# 59655     2959602                           64.0              M
# 59656     2959602                           64.0              M
# 59657     2959602                           64.0              M
# 59658     2959602                           64.0              M
# 59659     2959602                           64.0              M
# 59660     2959602                           64.0              M
# 59661     2959602                           64.0              M
# 59662     2959602                           64.0              M
#
#                  race_patient       ethnicity_patient  \
# 0                       White  Not Hispanic or Latino
# 1                       White  Not Hispanic or Latino
# 2                       White  Not Hispanic or Latino
# 3                       White  Not Hispanic or Latino
# 4                       White  Not Hispanic or Latino
# 5                       White  Not Hispanic or Latino
# 6                       White  Not Hispanic or Latino
# 7                       White  Not Hispanic or Latino
# 8                       White  Not Hispanic or Latino
# 9                       White  Not Hispanic or Latino
# 10                      White  Not Hispanic or Latino
# 11                      White  Not Hispanic or Latino
# 12                      White  Not Hispanic or Latino
# 13                      White  Not Hispanic or Latino
# 14                      White  Not Hispanic or Latino
# 15                      White  Not Hispanic or Latino
# 16                      White  Not Hispanic or Latino
# 17                      White  Not Hispanic or Latino
# 18                      White  Not Hispanic or Latino
# 19                      White  Not Hispanic or Latino
# 20                      White  Not Hispanic or Latino
# 21                      White  Not Hispanic or Latino
# 22                      White  Not Hispanic or Latino
# 23                      White  Not Hispanic or Latino
# 24                      White  Not Hispanic or Latino
# 25                      White  Not Hispanic or Latino
# 26                      White  Not Hispanic or Latino
# 27                      White  Not Hispanic or Latino
# 28                      White  Not Hispanic or Latino
# 29                      White  Not Hispanic or Latino
# ...                       ...                     ...
# 59633                   White  Not Hispanic or Latino
# 59634                   White  Not Hispanic or Latino
# 59635                   White  Not Hispanic or Latino
# 59636                   White  Not Hispanic or Latino
# 59637                   White  Not Hispanic or Latino
# 59638                   White  Not Hispanic or Latino
# 59639                   White  Not Hispanic or Latino
# 59640                   White  Not Hispanic or Latino
# 59641                   White  Not Hispanic or Latino
# 59642                   White  Not Hispanic or Latino
# 59643                   White  Not Hispanic or Latino
# 59644                   White  Not Hispanic or Latino
# 59645                   White  Not Hispanic or Latino
# 59646  Black/African-American  Not Hispanic or Latino
# 59647  Black/African-American  Not Hispanic or Latino
# 59648  Black/African-American  Not Hispanic or Latino
# 59649  Black/African-American  Not Hispanic or Latino
# 59650  Black/African-American  Not Hispanic or Latino
# 59651  Black/African-American  Not Hispanic or Latino
# 59652  Black/African-American  Not Hispanic or Latino
# 59653  Black/African-American  Not Hispanic or Latino
# 59654  Black/African-American  Not Hispanic or Latino
# 59655  Black/African-American  Not Hispanic or Latino
# 59656  Black/African-American  Not Hispanic or Latino
# 59657  Black/African-American  Not Hispanic or Latino
# 59658  Black/African-American  Not Hispanic or Latino
# 59659  Black/African-American  Not Hispanic or Latino
# 59660  Black/African-American  Not Hispanic or Latino
# 59661  Black/African-American  Not Hispanic or Latino
# 59662  Black/African-American  Not Hispanic or Latino
#
#        date_of_death_d_patient  encounter_id_radiology  \
# 0                          NaN                 4645531
# 1                          NaN                 5066736
# 2                          NaN                 5066736
# 3                          NaN                 5097355
# 4                          NaN                 6214618
# 5                          NaN                 6221749
# 6                          NaN                 6221749
# 7                          NaN                 6265020
# 8                          NaN                 6265020
# 9                          NaN                 6747726
# 10                         NaN                 6747726
# 11                         NaN                 7160379
# 12                         NaN                 8413485
# 13                         NaN                 8413485
# 14                         NaN                 9235183
# 15                         NaN                 9494644
# 16                         NaN                 9495002
# 17                         NaN                 9495002
# 18                         NaN                 9495002
# 19                         NaN                 9495002
# 20                         NaN                 9495002
# 21                         NaN                 9495002
# 22                         NaN                 9495002
# 23                         NaN                 9495002
# 24                         NaN                 9495002
# 25                         NaN                 9495002
# 26                         NaN                 9495002
# 27                         NaN                 9495002
# 28                         NaN                 9495002
# 29                         NaN                 9495002
# ...                        ...                     ...
# 59633                      NaN                11657247
# 59634                      NaN                12529024
# 59635                      NaN                12529024
# 59636                      NaN                12584673
# 59637                      NaN                12584673
# 59638                      NaN                12584673
# 59639                      NaN                12584673
# 59640                      NaN                12584673
# 59641                      NaN                12584673
# 59642                      NaN                12584673
# 59643                      NaN                12521405
# 59644                      NaN                12521405
# 59645                      NaN                12580704
# 59646                      NaN                12234386
# 59647                      NaN                12234386
# 59648                      NaN                12234386
# 59649  2018-12-08 00:00:00.000                12269769
# 59650  2018-12-08 00:00:00.000                12269769
# 59651  2018-12-08 00:00:00.000                12269769
# 59652  2018-12-08 00:00:00.000                12269769
# 59653  2018-12-08 00:00:00.000                12269769
# 59654  2018-12-08 00:00:00.000                12269769
# 59655  2018-12-08 00:00:00.000                12269769
# 59656  2018-12-08 00:00:00.000                12269769
# 59657  2018-12-08 00:00:00.000                12269769
# 59658  2018-12-08 00:00:00.000                12269769
# 59659  2018-12-08 00:00:00.000                12345049
# 59660  2018-12-08 00:00:00.000                12345049
# 59661  2018-12-08 00:00:00.000                12345049
# 59662  2018-12-08 00:00:00.000                12345049
#
#        order_proc_id_deid_radiology ordering_date_off_radiology  \
# 0                            856883     2013-08-22 00:00:00.000
# 1                            685083     2013-08-22 00:00:00.000
# 2                            719735     2013-08-22 00:00:00.000
# 3                            973439     2014-01-11 00:00:00.000
# 4                            852596     2014-06-22 00:00:00.000
# 5                            691513     2014-12-06 00:00:00.000
# 6                            993450     2014-12-06 00:00:00.000
# 7                            597997     2014-01-11 00:00:00.000
# 8                           1028470     2014-01-11 00:00:00.000
# 9                            884699     2014-06-28 00:00:00.000
# 10                          1280256     2014-06-28 00:00:00.000
# 11                          1363180     2014-12-06 00:00:00.000
# 12                           351492     2016-08-27 00:00:00.000
# 13                          1445308     2016-08-27 00:00:00.000
# 14                          1066104     2017-04-24 00:00:00.000
# 15                           354743     2017-09-01 00:00:00.000
# 16                           518948     2017-07-20 00:00:00.000
# 17                           519309     2017-07-20 00:00:00.000
# 18                           615980     2017-07-12 00:00:00.000
# 19                           630992     2017-06-29 00:00:00.000
# 20                           640493     2017-07-07 00:00:00.000
# 21                           652605     2017-07-12 00:00:00.000
# 22                           732678     2017-07-05 00:00:00.000
# 23                           898546     2017-07-03 00:00:00.000
# 24                           900467     2017-06-29 00:00:00.000
# 25                           929338     2017-07-13 00:00:00.000
# 26                           945319     2017-07-03 00:00:00.000
# 27                           981963     2017-07-16 00:00:00.000
# 28                          1009364     2017-07-13 00:00:00.000
# 29                          1025343     2017-07-20 00:00:00.000
# ...                             ...                         ...
# 59633                       1238113     2018-07-14 00:00:00.000
# 59634                       1365030     2018-09-09 00:00:00.000
# 59635                       1390748     2018-09-09 00:00:00.000
# 59636                        213630     2018-11-09 00:00:00.000
# 59637                        281783     2018-10-31 00:00:00.000
# 59638                        380540     2018-11-02 00:00:00.000
# 59639                        566268     2018-11-02 00:00:00.000
# 59640                        783714     2018-10-31 00:00:00.000
# 59641                       1018977     2018-10-31 00:00:00.000
# 59642                       1224385     2018-10-31 00:00:00.000
# 59643                        482014     2017-12-07 00:00:00.000
# 59644                        933730     2017-12-07 00:00:00.000
# 59645                       1355835     2017-12-02 00:00:00.000
# 59646                        724082     2018-09-09 00:00:00.000
# 59647                        782976     2018-09-09 00:00:00.000
# 59648                       1288252     2018-09-09 00:00:00.000
# 59649                        583492     2018-10-17 00:00:00.000
# 59650                        704238     2018-10-17 00:00:00.000
# 59651                        775072     2018-10-16 00:00:00.000
# 59652                        848263     2018-10-16 00:00:00.000
# 59653                       1009092     2018-10-16 00:00:00.000
# 59654                       1075162     2018-10-16 00:00:00.000
# 59655                       1165291     2018-10-16 00:00:00.000
# 59656                       1314416     2018-10-14 00:00:00.000
# 59657                       1315519     2018-10-14 00:00:00.000
# 59658                       1349234     2018-10-16 00:00:00.000
# 59659                         65973     2018-11-15 00:00:00.000
# 59660                        561872     2018-11-16 00:00:00.000
# 59661                        985122     2018-11-15 00:00:00.000
# 59662                       1002284     2018-11-16 00:00:00.000
#
#                          exam_type_radiology
# 0                        XR Chest PA/Lateral
# 1                        XR Chest PA/Lateral
# 2                        XR Chest PA/Lateral
# 3                        XR Chest PA/Lateral
# 4                                CT Chest wo
# 5                        XR Chest PA/Lateral
# 6                        XR Chest PA/Lateral
# 7                        XR Chest PA/Lateral
# 8                        XR Chest PA/Lateral
# 9                                CT Chest wo
# 10                               CT Chest wo
# 11                       XR Chest PA/Lateral
# 12          CT Angio Upper Extremity wwo, Lt
# 13                        CT Angio Chest wwo
# 14     CT Chest Low Dose Cancer Screening WO
# 15                               CT Chest wo
# 16                 XR Portable Chest, 1 View
# 17                     XR Port Chest, 1 View
# 18                     XR Port Chest, 1 View
# 19                             CT PE Chest w
# 20                     XR Port Chest, 1 View
# 21                     XR Port Chest, 1 View
# 22                     XR Port Chest, 1 View
# 23                     XR Port Chest, 1 View
# 24                             CT PE Chest w
# 25                               CT Chest wo
# 26                     XR Port Chest, 1 View
# 27                     XR Port Chest, 1 View
# 28                               CT Chest wo
# 29                 XR Portable Chest, 1 View
# ...                                      ...
# 59633                   IOE COM CT ANG CHEST
# 59634                            CT Chest wo
# 59635                            CT Chest wo
# 59636                            CT Chest wo
# 59637               XR Portable Chest, 1View
# 59638            CT Upper Abdomen & Pelvis w
# 59639            CT Upper Abdomen & Pelvis w
# 59640                    XR Chest PA/Lateral
# 59641                    XR Chest PA/Lateral
# 59642               XR Portable Chest, 1View
# 59643                            CT Chest wo
# 59644                            CT Chest wo
# 59645                            CT Chest wo
# 59646                    XR Chest PA/Lateral
# 59647                    XR Chest PA/Lateral
# 59648                    XR Chest PA/Lateral
# 59649                            CT Chest wo
# 59650                            CT Chest wo
# 59651                       IOE COM CT CHEST
# 59652                       IOE COM XR CHEST
# 59653                   IOE COM CT ANG CHEST
# 59654                       IOE COM CT CHEST
# 59655                   IOE COM CT ANG CHEST
# 59656                  XR Port Chest, 1 View
# 59657                  XR Port Chest, 1 View
# 59658                       IOE COM XR CHEST
# 59659                    XR Chest PA/Lateral
# 59660                            CT Chest wo
# 59661                    XR Chest PA/Lateral
# 59662                            CT Chest wo
#
# [59663 rows x 10 columns]

# %% [markdown]
# Looks good now. Full run. Comment out the suffix.

# %%
list_[4].iloc[0:5,:]
# Out:
#     patient_id  encounter_id_dx_info dx_1_dx_info  \
# 3          114               9494644         J849
# 15         114               6747726       786.50
# 21         114               5066736        786.2
# 26         672               9011341        R0602
# 34         114               9495002         J849
#
#                               dx_desc_1_dx_info  dx1_rank_dx_info  \
# 3   INTERSTITIAL PULMONARY DISEASE, UNSPECIFIED               1.0
# 15                       UNSPECIFIED CHEST PAIN               1.0
# 21                                        COUGH               1.0
# 26                          SHORTNESS OF BREATH               1.0
# 34  INTERSTITIAL PULMONARY DISEASE, UNSPECIFIED               1.0
#
#    dx_2_dx_info                                 dx_desc_2_dx_info  \
# 3          J849       INTERSTITIAL PULMONARY DISEASE, UNSPECIFIED
# 15       793.19  OTHER NONSPECIFIC ABNORMAL FINDING OF LUNG FIELD
# 21        305.1                 NONDEPENDENT TOBACCO USE DISORDER
# 26         R079                           CHEST PAIN, UNSPECIFIED
# 34        J9601            ACUTE RESPIRATORY FAILURE WITH HYPOXIA
#
#     dx2_rank_dx_info dx_3_dx_info                          dx_desc_3_dx_info  \
# 3                2.0          NaN                                        NaN
# 15               2.0          NaN                                        NaN
# 21               2.0          NaN                                        NaN
# 26               2.0         J449  CHRONIC OBSTRUCTIVE PULMONARY DISEASE USP
# 34               2.0         J189            PNEUMONIA, UNSPECIFIED ORGANISM
#
#           ...          dx83_rank_dx_info dx_84_dx_info dx_desc_84_dx_info  \
# 3         ...                        NaN           NaN                NaN
# 15        ...                        NaN           NaN                NaN
# 21        ...                        NaN           NaN                NaN
# 26        ...                        NaN           NaN                NaN
# 34        ...                        NaN           NaN                NaN
#
#     dx84_rank_dx_info dx_85_dx_info dx_desc_85_dx_info  dx85_rank_dx_info  \
# 3                 NaN           NaN                NaN                NaN
# 15                NaN           NaN                NaN                NaN
# 21                NaN           NaN                NaN                NaN
# 26                NaN           NaN                NaN                NaN
# 34                NaN           NaN                NaN                NaN
#
#    dx_86_dx_info dx_desc_86_dx_info  dx86_rank_dx_info
# 3            NaN                NaN                NaN
# 15           NaN                NaN                NaN
# 21           NaN                NaN                NaN
# 26           NaN                NaN                NaN
# 34           NaN                NaN                NaN
#
# [5 rows x 260 columns]

# %% [markdown]
# # Merge first grouping

# %%
onlyfiles1 = [join(mypath,f) for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
onlyfiles1
# Out:
# ['Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_1_MOVEDFROMCOHORT2.csv',
#  'Z:/FINAL OUTPUT v2/07_ENCOUNTER_SOCIAL_HX_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/09_DX_INFO_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/merged_cohort1.csv',
#  'Z:/FINAL OUTPUT v2/05_ENCOUNTER_PROVIDER_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/04_ENCOUNTER_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/06_ENCOUNTER_PROVIDER_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/02_PATIENT_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/merged_cohort2.csv',
#  'Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_2_NEW.csv',
#  'Z:/FINAL OUTPUT v2/03_ENCOUNTER_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/11_COHORT_1_RADIOLOGY.csv',
#  'Z:/FINAL OUTPUT v2/08_ENCOUNTER_SOCIAL_HX_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/10_DX_INFO_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/merged_cohort2_sampled.csv',
#  'Z:/FINAL OUTPUT v2/12_COHORT_2_RADIOLOGY.csv',
#  'Z:/FINAL OUTPUT v2/merged_movedfromcohort1.csv']

# %%
# ORDER NOW MATTERS
onlyfiles1 = list( onlyfiles1[i] for i in [2,11,3,12] )
onlyfiles1
# Out:
# ['Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/03_ENCOUNTER_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/09_DX_INFO_COHORT_1.csv',
#  'Z:/FINAL OUTPUT v2/11_COHORT_1_RADIOLOGY.csv']

# %%
patientlist = np.unique(pd.read_csv(onlyfiles1[0],sep="|").PATIENT_ID)
patientlist[0:5]
# Out:
# array([ 32124,  74912,  81545,  93110, 118647], dtype=int64)

# %% [markdown]
# # Function def
#
# Function to populate a list of dfs.

# %%
def get_list(listoffiles,like,patientids):
    for f in listoffiles:
        if f.find(like) == -1:
            print("skipped:",f)
        else:
            print("added to list_",f)
            df = pd.read_csv(f,index_col=None, header=0,sep="|")
            df.columns = [x.lower() for x in df.columns]
            df = df[df['patient_id'].isin(patientlist)]
            list_.append(df)
    suffix = ('_patient', '_encounter','_dx_info','radiology')
    for i in range(0,len(list_)):
        print("iteration number",i)
        print("suffix : ",suffix[i])
        if i == 0:
            tmp1 = pd.DataFrame(list_[i].iloc[:,0])
            list_[i] = list_[i].iloc[:,1:].add_suffix(suffix[i])
            list_[i] = pd.concat((tmp1,(list_[i])),axis=1)
            print("dimensions : ", list_[i].shape)
        else:
            tmp1 = pd.DataFrame(list_[i].iloc[:,0:2])
            list_[i] = list_[i].iloc[:,2:].add_suffix(suffix[i])
            list_[i] = pd.concat((tmp1,(list_[i])),axis=1)
            print("dimensions : ", list_[i].shape)

# %%
def merge_lists(data):
    for i in range(0,len(list_)):
        print(i)
        if i == 1:
            print("merging first list slice: ", i) 
            print(data[i].iloc[0:1,:])
            df1 = data[0]
            df2 = data[i]
            holdingdf = pd.merge(df1, df2, how='left', on=['patient_id'])
        if i > 1:
            print("merging next list slice: ", i)
            print(data[i].iloc[0:1,:])
            df1 = holdingdf
            df2 = data[i]
            holdingdf = pd.merge(df1, df2, how='left', on=['patient_id','encounter_id'])
    return(holdingdf)

# %% [markdown]
# # Now run list and merge functions on pop one

# %%
list_ = []
get_list(onlyfiles1,"COHORT",patientlist)
# Out:
# added to list_ Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_1.csv
# added to list_ Z:/FINAL OUTPUT v2/03_ENCOUNTER_COHORT_1.csv
# added to list_ Z:/FINAL OUTPUT v2/09_DX_INFO_COHORT_1.csv
# added to list_ Z:/FINAL OUTPUT v2/11_COHORT_1_RADIOLOGY.csv
# iteration number 0
# suffix :  _patient
# dimensions :  (126, 6)
# iteration number 1
# suffix :  _encounter
# dimensions :  (250, 19)
# iteration number 2
# suffix :  _dx_info
# dimensions :  (250, 41)
# iteration number 3
# suffix :  radiology
# dimensions :  (133, 5)

# %%
cohort1dta = merge_lists(list_)
# Out:
# 0
# 1
# merging first list slice:  1
#    patient_id  encounter_id enc_eio_encounter visit_status_1_encounter  \
# 0       32124       5039107                 O                Completed
#
#   visit_status_2_encounter visit_status_3_encounter  visit_status_4_encounter  \
# 0                      NaN                      NaN                       NaN
#
#       adm_date_d_encounter    disc_date_d_encounter   start_date_d_encounter  \
# 0  2012-08-01 00:00:00.000  2012-08-01 00:00:00.000  2012-08-01 00:00:00.000
#
#       end_date_d_encounter admit_source_1_encounter admit_source_2_encounter  \
# 0  2012-08-01 00:00:00.000                      NaN                      NaN
#
#    admit_source_3_encounter disch_disp_1_encounter  disch_disp_2_encounter  \
# 0                       NaN                    NaN                     NaN
#
#    disch_disp_3_encounter  zip_d_encounter enc_fin_class_encounter
# 0                     NaN           100058                Medicare
# 2
# merging next list slice:  2
#    patient_id  encounter_id dx_1_dx_info  \
# 0       32124       5039107       715.09
#
#                                    dx_desc_1_dx_info  dx1_rank_dx_info  \
# 0  OSTEOARTHROSIS GENERALIZED INVOLVING MULTIPLE ...                 1
#
#   dx_2_dx_info                      dx_desc_2_dx_info  dx2_rank_dx_info  \
# 0       275.49  OTHER DISORDERS OF CALCIUM METABOLISM               2.0
#
#   dx_3_dx_info                                  dx_desc_3_dx_info  \
# 0       712.31  CHONDROCALCINOSIS CAUSE UNSPECIFIED INVOLVING ...
#
#          ...          dx10_rank_dx_info dx_11_dx_info dx_desc_11_dx_info  \
# 0        ...                        NaN           NaN                NaN
#
#    dx11_rank_dx_info dx_12_dx_info dx_desc_12_dx_info  dx12_rank_dx_info  \
# 0                NaN           NaN                NaN                NaN
#
#   dx_13_dx_info dx_desc_13_dx_info  dx13_rank_dx_info
# 0           NaN                NaN                NaN
#
# [1 rows x 41 columns]
# 3
# merging next list slice:  3
#    patient_id  encounter_id  order_proc_id_deidradiology  \
# 0     1557194       4441339                       680984
#
#   ordering_date_offradiology exam_type\t\tradiology
# 0    2012-06-19 00:00:00.000    XR Chest PA/Lateral

# %%
cohort1dta.head()
# Out:
#    patient_id  age_at_last_encounter_patient gender_patient  \
# 0       32124                           90.0              F
# 1       74912                           63.0              F
# 2       81545                           65.0              M
# 3       93110                           47.0              F
# 4      118647                           52.0              F
#
#              race_patient       ethnicity_patient  date_of_death_d_patient  \
# 0                   White  Not Hispanic or Latino                      NaN
# 1  Black/African-American  Not Hispanic or Latino                      NaN
# 2                   White  Not Hispanic or Latino  2015-06-21 00:00:00.000
# 3  Black/African-American  Not Hispanic or Latino  2013-04-07 00:00:00.000
# 4  Black/African-American  Not Hispanic or Latino                      NaN
#
#    encounter_id enc_eio_encounter visit_status_1_encounter  \
# 0       5039107                 O                Completed
# 1       5237464                 O                Completed
# 2       4429153                 O                Completed
# 3       5226111                 O                Completed
# 4       6862790                 O                Completed
#
#   visit_status_2_encounter           ...            dx11_rank_dx_info  \
# 0                      NaN           ...                          NaN
# 1                      NaN           ...                          NaN
# 2                 Canceled           ...                          NaN
# 3                 Canceled           ...                          NaN
# 4                      NaN           ...                          NaN
#
#    dx_12_dx_info dx_desc_12_dx_info dx12_rank_dx_info dx_13_dx_info  \
# 0            NaN                NaN               NaN           NaN
# 1            NaN                NaN               NaN           NaN
# 2            NaN                NaN               NaN           NaN
# 3            NaN                NaN               NaN           NaN
# 4            NaN                NaN               NaN           NaN
#
#   dx_desc_13_dx_info dx13_rank_dx_info order_proc_id_deidradiology  \
# 0                NaN               NaN                         NaN
# 1                NaN               NaN                         NaN
# 2                NaN               NaN                         NaN
# 3                NaN               NaN                         NaN
# 4                NaN               NaN                    178548.0
#
#    ordering_date_offradiology   exam_type\t\tradiology
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2                         NaN                      NaN
# 3                         NaN                      NaN
# 4     2016-05-11 00:00:00.000  XR Chest PA/Lateral\t\t
#
# [5 rows x 66 columns]

# %%
cohort1dta.to_csv(join(mypath,"merged_cohort1.csv"),sep="|",index=False)

# %% [markdown]
# # Quick note
#
# Differences in dx columns. Need to account for that in the union of the two.

# %% [markdown]
# # Below we merge the moved from cohort 2 grouping

# %%
# ORDER NOW MATTERS
onlyfiles3editshort = list( onlyfiles2edit[i] for i in [0,1,4,5] )
onlyfiles3editshort
# Out:
# ['Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_1_MOVEDFROMCOHORT2.csv',
#  'Z:/FINAL OUTPUT v2/04_ENCOUNTER_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/10_DX_INFO_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/12_COHORT_2_RADIOLOGY.csv']

# %%
list_ = []

get_list(onlyfiles3editshort,"COHORT",patientlist)
# Out:
# added to list_ Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_1_MOVEDFROMCOHORT2.csv
# added to list_ Z:/FINAL OUTPUT v2/04_ENCOUNTER_COHORT_2.csv
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2856: DtypeWarning: Columns (6,13,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# added to list_ Z:/FINAL OUTPUT v2/10_DX_INFO_COHORT_2.csv
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2856: DtypeWarning: Columns (98,110,113,116,117,119,120,122,123,125,126,128,129,131,132,134,135,137,138,140,141,143,144,146,147,149,150,152,153,155,156,158,159,161,162,164,165,167,168,170,171,173,174,176,177,179,180,182,183,185,186,188,189,191,192,194,195,197,198,200,201,203,204,206,207,209,210,212,213,215,216,218,219,221,222,224,225,227,228,230,231,233,234,236,237,239,240,242,243,245,246,248,249,251,252,254,255,257,258) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# added to list_ Z:/FINAL OUTPUT v2/12_COHORT_2_RADIOLOGY.csv
# iteration number 0
# suffix :  _patient
# dimensions :  (2243, 6)
# iteration number 1
# suffix :  _encounter
# dimensions :  (396632, 19)
# iteration number 2
# suffix :  _dx_info
# dimensions :  (396632, 260)
# iteration number 3
# suffix :  radiology
# dimensions :  (1275948, 5)

# %%
holdingdf = pd.DataFrame()
cohort1_dta_part2 = merge_lists(list_)
# Out:
# 0
# 1
# merging first list slice:  1
#    patient_id  encounter_id enc_eio_encounter visit_status_1_encounter  \
# 0          49       4860489                 O                Completed
#
#   visit_status_2_encounter visit_status_3_encounter visit_status_4_encounter  \
# 0                      NaN                      NaN                      NaN
#
#       adm_date_d_encounter    disc_date_d_encounter   start_date_d_encounter  \
# 0  2012-07-17 00:00:00.000  2012-07-17 00:00:00.000  2012-07-17 00:00:00.000
#
#       end_date_d_encounter     admit_source_1_encounter  \
# 0  2012-07-17 00:00:00.000  Clinic or Physicians Office
#
#   admit_source_2_encounter admit_source_3_encounter disch_disp_1_encounter  \
# 0                      NaN                      NaN                    NaN
#
#   disch_disp_2_encounter disch_disp_3_encounter  zip_d_encounter  \
# 0                    NaN                    NaN           113043
#
#   enc_fin_class_encounter
# 0                Medicare
# 2
# merging next list slice:  2
#    patient_id  encounter_id dx_1_dx_info dx_desc_1_dx_info  dx1_rank_dx_info  \
# 0          49       4860489        786.2             COUGH               1.0
#
#   dx_2_dx_info   dx_desc_2_dx_info  dx2_rank_dx_info dx_3_dx_info  \
# 0       493.90  ASTHMA UNSPECIFIED               2.0          496
#
#                                    dx_desc_3_dx_info        ...          \
# 0  CHRONIC AIRWAY OBSTRUCTION NOT ELSEWHERE CLASS...        ...
#
#    dx83_rank_dx_info dx_84_dx_info dx_desc_84_dx_info  dx84_rank_dx_info  \
# 0                NaN           NaN                NaN                NaN
#
#   dx_85_dx_info dx_desc_85_dx_info  dx85_rank_dx_info dx_86_dx_info  \
# 0           NaN                NaN                NaN           NaN
#
#   dx_desc_86_dx_info  dx86_rank_dx_info
# 0                NaN                NaN
#
# [1 rows x 260 columns]
# 3
# merging next list slice:  3
#    patient_id  encounter_id  order_proc_id_deidradiology  \
# 0      155043        155164                       393037
#
#   ordering_date_offradiology       exam_typeradiology
# 0    2013-04-26 00:00:00.000  CT Upper Abd & Pelvis w

# %%
cohort1_dta_part2[cohort1_dta_part2['patient_id']==114]
# Out:
#     patient_id  age_at_last_encounter_patient gender_patient race_patient  \
# 0          114                           66.0              F        White
# 1          114                           66.0              F        White
# 2          114                           66.0              F        White
# 3          114                           66.0              F        White
# 4          114                           66.0              F        White
# 5          114                           66.0              F        White
# 6          114                           66.0              F        White
# 7          114                           66.0              F        White
# 8          114                           66.0              F        White
# 9          114                           66.0              F        White
# 10         114                           66.0              F        White
# 11         114                           66.0              F        White
# 12         114                           66.0              F        White
# 13         114                           66.0              F        White
# 14         114                           66.0              F        White
# 15         114                           66.0              F        White
# 16         114                           66.0              F        White
# 17         114                           66.0              F        White
# 18         114                           66.0              F        White
# 19         114                           66.0              F        White
# 20         114                           66.0              F        White
# 21         114                           66.0              F        White
# 22         114                           66.0              F        White
# 23         114                           66.0              F        White
# 24         114                           66.0              F        White
# 25         114                           66.0              F        White
# 26         114                           66.0              F        White
# 27         114                           66.0              F        White
# 28         114                           66.0              F        White
# 29         114                           66.0              F        White
# 30         114                           66.0              F        White
# 31         114                           66.0              F        White
# 32         114                           66.0              F        White
# 33         114                           66.0              F        White
# 34         114                           66.0              F        White
# 35         114                           66.0              F        White
# 36         114                           66.0              F        White
# 37         114                           66.0              F        White
# 38         114                           66.0              F        White
# 39         114                           66.0              F        White
# 40         114                           66.0              F        White
# 41         114                           66.0              F        White
# 42         114                           66.0              F        White
# 43         114                           66.0              F        White
# 44         114                           66.0              F        White
#
#          ethnicity_patient date_of_death_d_patient  encounter_id  \
# 0   Not Hispanic or Latino                     NaN       4645531
# 1   Not Hispanic or Latino                     NaN       5066736
# 2   Not Hispanic or Latino                     NaN       5066736
# 3   Not Hispanic or Latino                     NaN       5097355
# 4   Not Hispanic or Latino                     NaN       6214618
# 5   Not Hispanic or Latino                     NaN       6221749
# 6   Not Hispanic or Latino                     NaN       6221749
# 7   Not Hispanic or Latino                     NaN       6265020
# 8   Not Hispanic or Latino                     NaN       6265020
# 9   Not Hispanic or Latino                     NaN       6747726
# 10  Not Hispanic or Latino                     NaN       6747726
# 11  Not Hispanic or Latino                     NaN       7160379
# 12  Not Hispanic or Latino                     NaN       8413485
# 13  Not Hispanic or Latino                     NaN       8413485
# 14  Not Hispanic or Latino                     NaN       9235183
# 15  Not Hispanic or Latino                     NaN       9494644
# 16  Not Hispanic or Latino                     NaN       9495002
# 17  Not Hispanic or Latino                     NaN       9495002
# 18  Not Hispanic or Latino                     NaN       9495002
# 19  Not Hispanic or Latino                     NaN       9495002
# 20  Not Hispanic or Latino                     NaN       9495002
# 21  Not Hispanic or Latino                     NaN       9495002
# 22  Not Hispanic or Latino                     NaN       9495002
# 23  Not Hispanic or Latino                     NaN       9495002
# 24  Not Hispanic or Latino                     NaN       9495002
# 25  Not Hispanic or Latino                     NaN       9495002
# 26  Not Hispanic or Latino                     NaN       9495002
# 27  Not Hispanic or Latino                     NaN       9495002
# 28  Not Hispanic or Latino                     NaN       9495002
# 29  Not Hispanic or Latino                     NaN       9495002
# 30  Not Hispanic or Latino                     NaN       9495002
# 31  Not Hispanic or Latino                     NaN       9495002
# 32  Not Hispanic or Latino                     NaN       9495002
# 33  Not Hispanic or Latino                     NaN       9495002
# 34  Not Hispanic or Latino                     NaN       9495002
# 35  Not Hispanic or Latino                     NaN       9495002
# 36  Not Hispanic or Latino                     NaN       9495002
# 37  Not Hispanic or Latino                     NaN       9495002
# 38  Not Hispanic or Latino                     NaN       9640850
# 39  Not Hispanic or Latino                     NaN       9640850
# 40  Not Hispanic or Latino                     NaN      12338862
# 41  Not Hispanic or Latino                     NaN      12384448
# 42  Not Hispanic or Latino                     NaN      12384448
# 43  Not Hispanic or Latino                     NaN      12519104
# 44  Not Hispanic or Latino                     NaN      12519104
#
#    enc_eio_encounter visit_status_1_encounter visit_status_2_encounter  \
# 0                  O                Completed                 Canceled
# 1                  O                Completed                      NaN
# 2                  O                Completed                      NaN
# 3                  O                Completed                      NaN
# 4                  O                Completed                 Canceled
# 5                  O                Completed                      NaN
# 6                  O                Completed                      NaN
# 7                  O                Completed                      NaN
# 8                  O                Completed                      NaN
# 9                  O                Completed                 Canceled
# 10                 O                Completed                 Canceled
# 11                 O                Completed                      NaN
# 12                 O                Completed                 Canceled
# 13                 O                Completed                 Canceled
# 14                 O                Completed                      NaN
# 15                 O                Completed                 Canceled
# 16                 I                  No Show                Completed
# 17                 I                  No Show                Completed
# 18                 I                  No Show                Completed
# 19                 I                  No Show                Completed
# 20                 I                  No Show                Completed
# 21                 I                  No Show                Completed
# 22                 I                  No Show                Completed
# 23                 I                  No Show                Completed
# 24                 I                  No Show                Completed
# 25                 I                  No Show                Completed
# 26                 I                  No Show                Completed
# 27                 I                  No Show                Completed
# 28                 I                  No Show                Completed
# 29                 I                  No Show                Completed
# 30                 I                  No Show                Completed
# 31                 I                  No Show                Completed
# 32                 I                  No Show                Completed
# 33                 I                  No Show                Completed
# 34                 I                  No Show                Completed
# 35                 I                  No Show                Completed
# 36                 I                  No Show                Completed
# 37                 I                  No Show                Completed
# 38                 O                Completed                 Canceled
# 39                 O                Completed                 Canceled
# 40                 O                Completed                      NaN
# 41                 O                Completed                 Canceled
# 42                 O                Completed                 Canceled
# 43                 E                Completed                      NaN
# 44                 E                Completed                      NaN
#
#                     ...                   dx84_rank_dx_info dx_85_dx_info  \
# 0                   ...                                 NaN           NaN
# 1                   ...                                 NaN           NaN
# 2                   ...                                 NaN           NaN
# 3                   ...                                 NaN           NaN
# 4                   ...                                 NaN           NaN
# 5                   ...                                 NaN           NaN
# 6                   ...                                 NaN           NaN
# 7                   ...                                 NaN           NaN
# 8                   ...                                 NaN           NaN
# 9                   ...                                 NaN           NaN
# 10                  ...                                 NaN           NaN
# 11                  ...                                 NaN           NaN
# 12                  ...                                 NaN           NaN
# 13                  ...                                 NaN           NaN
# 14                  ...                                 NaN           NaN
# 15                  ...                                 NaN           NaN
# 16                  ...                                 NaN           NaN
# 17                  ...                                 NaN           NaN
# 18                  ...                                 NaN           NaN
# 19                  ...                                 NaN           NaN
# 20                  ...                                 NaN           NaN
# 21                  ...                                 NaN           NaN
# 22                  ...                                 NaN           NaN
# 23                  ...                                 NaN           NaN
# 24                  ...                                 NaN           NaN
# 25                  ...                                 NaN           NaN
# 26                  ...                                 NaN           NaN
# 27                  ...                                 NaN           NaN
# 28                  ...                                 NaN           NaN
# 29                  ...                                 NaN           NaN
# 30                  ...                                 NaN           NaN
# 31                  ...                                 NaN           NaN
# 32                  ...                                 NaN           NaN
# 33                  ...                                 NaN           NaN
# 34                  ...                                 NaN           NaN
# 35                  ...                                 NaN           NaN
# 36                  ...                                 NaN           NaN
# 37                  ...                                 NaN           NaN
# 38                  ...                                 NaN           NaN
# 39                  ...                                 NaN           NaN
# 40                  ...                                 NaN           NaN
# 41                  ...                                 NaN           NaN
# 42                  ...                                 NaN           NaN
# 43                  ...                                 NaN           NaN
# 44                  ...                                 NaN           NaN
#
#    dx_desc_85_dx_info dx85_rank_dx_info dx_86_dx_info dx_desc_86_dx_info  \
# 0                 NaN               NaN           NaN                NaN
# 1                 NaN               NaN           NaN                NaN
# 2                 NaN               NaN           NaN                NaN
# 3                 NaN               NaN           NaN                NaN
# 4                 NaN               NaN           NaN                NaN
# 5                 NaN               NaN           NaN                NaN
# 6                 NaN               NaN           NaN                NaN
# 7                 NaN               NaN           NaN                NaN
# 8                 NaN               NaN           NaN                NaN
# 9                 NaN               NaN           NaN                NaN
# 10                NaN               NaN           NaN                NaN
# 11                NaN               NaN           NaN                NaN
# 12                NaN               NaN           NaN                NaN
# 13                NaN               NaN           NaN                NaN
# 14                NaN               NaN           NaN                NaN
# 15                NaN               NaN           NaN                NaN
# 16                NaN               NaN           NaN                NaN
# 17                NaN               NaN           NaN                NaN
# 18                NaN               NaN           NaN                NaN
# 19                NaN               NaN           NaN                NaN
# 20                NaN               NaN           NaN                NaN
# 21                NaN               NaN           NaN                NaN
# 22                NaN               NaN           NaN                NaN
# 23                NaN               NaN           NaN                NaN
# 24                NaN               NaN           NaN                NaN
# 25                NaN               NaN           NaN                NaN
# 26                NaN               NaN           NaN                NaN
# 27                NaN               NaN           NaN                NaN
# 28                NaN               NaN           NaN                NaN
# 29                NaN               NaN           NaN                NaN
# 30                NaN               NaN           NaN                NaN
# 31                NaN               NaN           NaN                NaN
# 32                NaN               NaN           NaN                NaN
# 33                NaN               NaN           NaN                NaN
# 34                NaN               NaN           NaN                NaN
# 35                NaN               NaN           NaN                NaN
# 36                NaN               NaN           NaN                NaN
# 37                NaN               NaN           NaN                NaN
# 38                NaN               NaN           NaN                NaN
# 39                NaN               NaN           NaN                NaN
# 40                NaN               NaN           NaN                NaN
# 41                NaN               NaN           NaN                NaN
# 42                NaN               NaN           NaN                NaN
# 43                NaN               NaN           NaN                NaN
# 44                NaN               NaN           NaN                NaN
#
#    dx86_rank_dx_info order_proc_id_deidradiology ordering_date_offradiology  \
# 0                NaN                    856883.0    2013-08-22 00:00:00.000
# 1                NaN                    685083.0    2013-08-22 00:00:00.000
# 2                NaN                    719735.0    2013-08-22 00:00:00.000
# 3                NaN                    973439.0    2014-01-11 00:00:00.000
# 4                NaN                    852596.0    2014-06-22 00:00:00.000
# 5                NaN                    691513.0    2014-12-06 00:00:00.000
# 6                NaN                    993450.0    2014-12-06 00:00:00.000
# 7                NaN                    597997.0    2014-01-11 00:00:00.000
# 8                NaN                   1028470.0    2014-01-11 00:00:00.000
# 9                NaN                    884699.0    2014-06-28 00:00:00.000
# 10               NaN                   1280256.0    2014-06-28 00:00:00.000
# 11               NaN                   1363180.0    2014-12-06 00:00:00.000
# 12               NaN                    351492.0    2016-08-27 00:00:00.000
# 13               NaN                   1445308.0    2016-08-27 00:00:00.000
# 14               NaN                   1066104.0    2017-04-24 00:00:00.000
# 15               NaN                    354743.0    2017-09-01 00:00:00.000
# 16               NaN                    518948.0    2017-07-20 00:00:00.000
# 17               NaN                    519309.0    2017-07-20 00:00:00.000
# 18               NaN                    615980.0    2017-07-12 00:00:00.000
# 19               NaN                    630992.0    2017-06-29 00:00:00.000
# 20               NaN                    640493.0    2017-07-07 00:00:00.000
# 21               NaN                    652605.0    2017-07-12 00:00:00.000
# 22               NaN                    732678.0    2017-07-05 00:00:00.000
# 23               NaN                    898546.0    2017-07-03 00:00:00.000
# 24               NaN                    900467.0    2017-06-29 00:00:00.000
# 25               NaN                    929338.0    2017-07-13 00:00:00.000
# 26               NaN                    945319.0    2017-07-03 00:00:00.000
# 27               NaN                    981963.0    2017-07-16 00:00:00.000
# 28               NaN                   1009364.0    2017-07-13 00:00:00.000
# 29               NaN                   1025343.0    2017-07-20 00:00:00.000
# 30               NaN                   1026389.0    2017-07-16 00:00:00.000
# 31               NaN                   1031787.0    2017-07-07 00:00:00.000
# 32               NaN                   1095278.0    2017-07-11 00:00:00.000
# 33               NaN                   1107847.0    2017-07-05 00:00:00.000
# 34               NaN                   1144716.0    2017-07-11 00:00:00.000
# 35               NaN                   1228853.0    2017-07-20 00:00:00.000
# 36               NaN                   1349634.0    2017-06-29 00:00:00.000
# 37               NaN                   1395006.0    2017-06-29 00:00:00.000
# 38               NaN                    161409.0    2017-09-16 00:00:00.000
# 39               NaN                    682672.0    2017-09-16 00:00:00.000
# 40               NaN                    535658.0    2018-09-20 00:00:00.000
# 41               NaN                    860334.0    2018-11-11 00:00:00.000
# 42               NaN                   1287776.0    2018-11-11 00:00:00.000
# 43               NaN                     82700.0    2018-09-27 00:00:00.000
# 44               NaN                    987921.0    2018-09-27 00:00:00.000
#
#                        exam_typeradiology
# 0                     XR Chest PA/Lateral
# 1                     XR Chest PA/Lateral
# 2                     XR Chest PA/Lateral
# 3                     XR Chest PA/Lateral
# 4                             CT Chest wo
# 5                     XR Chest PA/Lateral
# 6                     XR Chest PA/Lateral
# 7                     XR Chest PA/Lateral
# 8                     XR Chest PA/Lateral
# 9                             CT Chest wo
# 10                            CT Chest wo
# 11                    XR Chest PA/Lateral
# 12       CT Angio Upper Extremity wwo, Lt
# 13                     CT Angio Chest wwo
# 14  CT Chest Low Dose Cancer Screening WO
# 15                            CT Chest wo
# 16              XR Portable Chest, 1 View
# 17                  XR Port Chest, 1 View
# 18                  XR Port Chest, 1 View
# 19                          CT PE Chest w
# 20                  XR Port Chest, 1 View
# 21                  XR Port Chest, 1 View
# 22                  XR Port Chest, 1 View
# 23                  XR Port Chest, 1 View
# 24                          CT PE Chest w
# 25                            CT Chest wo
# 26                  XR Port Chest, 1 View
# 27                  XR Port Chest, 1 View
# 28                            CT Chest wo
# 29              XR Portable Chest, 1 View
# 30                  XR Port Chest, 1 View
# 31                  XR Port Chest, 1 View
# 32                  XR Port Chest, 1 View
# 33                  XR Port Chest, 1 View
# 34                  XR Port Chest, 1 View
# 35                  XR Port Chest, 1 View
# 36                    XR Chest PA/Lateral
# 37                    XR Chest PA/Lateral
# 38                            CT Chest wo
# 39                            CT Chest wo
# 40                    XR Chest PA/Lateral
# 41                            CT Chest wo
# 42                            CT Chest wo
# 43               XR Portable Chest, 1View
# 44               XR Portable Chest, 1View
#
# [45 rows x 285 columns]

# %%
cohort1_dta_part2.head()
# Out:
#    patient_id  age_at_last_encounter_patient gender_patient race_patient  \
# 0         114                           66.0              F        White
# 1         114                           66.0              F        White
# 2         114                           66.0              F        White
# 3         114                           66.0              F        White
# 4         114                           66.0              F        White
#
#         ethnicity_patient date_of_death_d_patient  encounter_id  \
# 0  Not Hispanic or Latino                     NaN       4645531
# 1  Not Hispanic or Latino                     NaN       5066736
# 2  Not Hispanic or Latino                     NaN       5066736
# 3  Not Hispanic or Latino                     NaN       5097355
# 4  Not Hispanic or Latino                     NaN       6214618
#
#   enc_eio_encounter visit_status_1_encounter visit_status_2_encounter  \
# 0                 O                Completed                 Canceled
# 1                 O                Completed                      NaN
# 2                 O                Completed                      NaN
# 3                 O                Completed                      NaN
# 4                 O                Completed                 Canceled
#
#           ...          dx84_rank_dx_info dx_85_dx_info dx_desc_85_dx_info  \
# 0         ...                        NaN           NaN                NaN
# 1         ...                        NaN           NaN                NaN
# 2         ...                        NaN           NaN                NaN
# 3         ...                        NaN           NaN                NaN
# 4         ...                        NaN           NaN                NaN
#
#   dx85_rank_dx_info dx_86_dx_info dx_desc_86_dx_info dx86_rank_dx_info  \
# 0               NaN           NaN                NaN               NaN
# 1               NaN           NaN                NaN               NaN
# 2               NaN           NaN                NaN               NaN
# 3               NaN           NaN                NaN               NaN
# 4               NaN           NaN                NaN               NaN
#
#   order_proc_id_deidradiology ordering_date_offradiology   exam_typeradiology
# 0                    856883.0    2013-08-22 00:00:00.000  XR Chest PA/Lateral
# 1                    685083.0    2013-08-22 00:00:00.000  XR Chest PA/Lateral
# 2                    719735.0    2013-08-22 00:00:00.000  XR Chest PA/Lateral
# 3                    973439.0    2014-01-11 00:00:00.000  XR Chest PA/Lateral
# 4                    852596.0    2014-06-22 00:00:00.000          CT Chest wo
#
# [5 rows x 285 columns]

# %% [markdown]
# We finally have a merged dataset that should be clean of dupes.

# %%
cohort1_dta_part2.to_csv(join(mypath,"merged_movedfromcohort1.csv"),sep="|")

# %% [markdown]
# # Merge of the first and second cohort1 groupings.
#
# Note that there's two different column sets

# %%
pd.set_option('display.max_columns', None)

# %%
# if from before. read in csvs

cohort1dta = pd.read_csv(join(mypath,"merged_cohort1.csv"),sep="|")
cohort1_dta_part2=pd.read_csv(join(mypath,"merged_movedfromcohort1.csv"),sep="|")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (19,22,109,110,112,113,115,116,118,119,121,122,124,125,127,128,130,131,133,134,136,137,139,140,142,143,145,146,148,149,151,152,154,155,157,158,160,161,163,164,166,167,169,170,172,173,175,176,178,179,181,182,184,185,187,188,190,191,193,194,196,197,199,200,202,203,205,206,208,209,211,212,214,215,217,218,220,221,223,224) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
cohort1dta[cohort1dta.patient_id==360469].columns
# Out:
# Index(['patient_id', 'age_at_last_encounter_patient', 'gender_patient',
#        'race_patient', 'ethnicity_patient', 'date_of_death_d_patient',
#        'encounter_id', 'enc_eio_encounter', 'visit_status_1_encounter',
#        'visit_status_2_encounter', 'visit_status_3_encounter',
#        'visit_status_4_encounter', 'adm_date_d_encounter',
#        'disc_date_d_encounter', 'start_date_d_encounter',
#        'end_date_d_encounter', 'admit_source_1_encounter',
#        'admit_source_2_encounter', 'admit_source_3_encounter',
#        'disch_disp_1_encounter', 'disch_disp_2_encounter',
#        'disch_disp_3_encounter', 'zip_d_encounter', 'enc_fin_class_encounter',
#        'dx_1_dx_info', 'dx_desc_1_dx_info', 'dx1_rank_dx_info', 'dx_2_dx_info',
#        'dx_desc_2_dx_info', 'dx2_rank_dx_info', 'dx_3_dx_info',
#        'dx_desc_3_dx_info', 'dx3_rank_dx_info', 'dx_4_dx_info',
#        'dx_desc_4_dx_info', 'dx4_rank_dx_info', 'dx_5_dx_info',
#        'dx_desc_5_dx_info', 'dx5_rank_dx_info', 'dx_6_dx_info',
#        'dx_desc_6_dx_info', 'dx6_rank_dx_info', 'dx_7_dx_info',
#        'dx_desc_7_dx_info', 'dx7_rank_dx_info', 'dx_8_dx_info',
#        'dx_desc_8_dx_info', 'dx8_rank_dx_info', 'dx_9_dx_info',
#        'dx_desc_9_dx_info', 'dx9_rank_dx_info', 'dx_10_dx_info',
#        'dx_desc_10_dx_info', 'dx10_rank_dx_info', 'dx_11_dx_info',
#        'dx_desc_11_dx_info', 'dx11_rank_dx_info', 'dx_12_dx_info',
#        'dx_desc_12_dx_info', 'dx12_rank_dx_info', 'dx_13_dx_info',
#        'dx_desc_13_dx_info', 'dx13_rank_dx_info',
#        'order_proc_id_deidradiology', 'ordering_date_offradiology',
#        'exam_typeradiology'],
#       dtype='object')

# %%
cohort1dta.rename(columns={'exam_type\t\tradiology':'exam_typeradiology'}, inplace=True)

# %%
cohort1_dta_part2[cohort1_dta_part2.patient_id==2959602].columns
# Out:
# Index(['Unnamed: 0', 'patient_id', 'age_at_last_encounter_patient',
#        'gender_patient', 'race_patient', 'ethnicity_patient',
#        'date_of_death_d_patient', 'encounter_id', 'enc_eio_encounter',
#        'visit_status_1_encounter',
#        ...
#        'dx84_rank_dx_info', 'dx_85_dx_info', 'dx_desc_85_dx_info',
#        'dx85_rank_dx_info', 'dx_86_dx_info', 'dx_desc_86_dx_info',
#        'dx86_rank_dx_info', 'order_proc_id_deidradiology',
#        'ordering_date_offradiology', 'exam_typeradiology'],
#       dtype='object', length=286)

# %%
cohort1_dta_part2[cohort1_dta_part2.patient_id==2959602][['patient_id','exam_typeradiology']]
# Out:
#        patient_id     exam_typeradiology
# 59651     2959602            CT Chest wo
# 59652     2959602            CT Chest wo
# 59653     2959602       IOE COM CT CHEST
# 59654     2959602       IOE COM XR CHEST
# 59655     2959602   IOE COM CT ANG CHEST
# 59656     2959602       IOE COM CT CHEST
# 59657     2959602   IOE COM CT ANG CHEST
# 59658     2959602  XR Port Chest, 1 View
# 59659     2959602  XR Port Chest, 1 View
# 59660     2959602       IOE COM XR CHEST
# 59661     2959602    XR Chest PA/Lateral
# 59662     2959602            CT Chest wo
# 59663     2959602    XR Chest PA/Lateral
# 59664     2959602            CT Chest wo

# %%
cohort1total = pd.merge(cohort1dta,cohort1_dta_part2,how="outer")

# %%
cohort1total.to_csv(join(mypath,"merged_cohort1_withcohort2.csv"),sep="|")

# %% [markdown]
# # Now merge for the cohort2 sample group

# %%
# ORDER NOW MATTERS
onlyfilessampled = [join(mypath,f) for f in listdir(mypath) if isfile(join(mypath, f))]
onlyfilessampled = list( onlyfilessampled[i] for i in [10,6,14,15] )
onlyfilessampled
# Out:
# ['Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_2_NEW.csv',
#  'Z:/FINAL OUTPUT v2/04_ENCOUNTER_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/10_DX_INFO_COHORT_2.csv',
#  'Z:/FINAL OUTPUT v2/12_COHORT_2_RADIOLOGY.csv']

# %%
patientlist = np.unique(cohort2sampdf.PATIENT_ID)
patientlist[0:5]
# Out:
# array([ 99, 195, 219, 256, 560], dtype=int64)

# %%
# memory errors still. merge the first part, return as object, try merge that way?

frame = pd.DataFrame()
list_ = []

def get_list(listoffiles,like,patientids):
    for f in listoffiles:
        if f.find(like) == -1:
            print("skipped:",f)
        else:
            print("added to list_",f)
            df = pd.read_csv(f,index_col=None, header=0,sep="|")
            df.columns = [x.lower() for x in df.columns]
            df = df[df['patient_id'].isin(patientlist)]
            list_.append(df)
    suffix = ('_patient', '_encounter','_dx_info','radiology')
    for i in range(0,len(list_)):
        print("iteration number",i)
        print("suffix : ",suffix[i])
        if i == 0:
            tmp1 = pd.DataFrame(list_[i].iloc[:,0])
            list_[i] = list_[i].iloc[:,1:].add_suffix(suffix[i])
            list_[i] = pd.concat((tmp1,(list_[i])),axis=1)
            print("dimensions : ", list_[i].shape)
        else:
            tmp1 = pd.DataFrame(list_[i].iloc[:,0:2])
            list_[i] = list_[i].iloc[:,2:].add_suffix(suffix[i])
            list_[i] = pd.concat((tmp1,(list_[i])),axis=1)
            print("dimensions : ", list_[i].shape)

# %%
get_list(onlyfilessampled,"COHORT",patientlist)
# Out:
# added to list_ Z:/FINAL OUTPUT v2/01_PATIENT_COHORT_2_NEW.csv
# added to list_ Z:/FINAL OUTPUT v2/04_ENCOUNTER_COHORT_2.csv
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2856: DtypeWarning: Columns (6,13,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# added to list_ Z:/FINAL OUTPUT v2/10_DX_INFO_COHORT_2.csv
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2856: DtypeWarning: Columns (98,110,113,116,117,119,120,122,123,125,126,128,129,131,132,134,135,137,138,140,141,143,144,146,147,149,150,152,153,155,156,158,159,161,162,164,165,167,168,170,171,173,174,176,177,179,180,182,183,185,186,188,189,191,192,194,195,197,198,200,201,203,204,206,207,209,210,212,213,215,216,218,219,221,222,224,225,227,228,230,231,233,234,236,237,239,240,242,243,245,246,248,249,251,252,254,255,257,258) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# added to list_ Z:/FINAL OUTPUT v2/12_COHORT_2_RADIOLOGY.csv
# iteration number 0
# suffix :  _patient
# dimensions :  (30000, 6)
# iteration number 1
# suffix :  _encounter
# dimensions :  (95743, 19)
# iteration number 2
# suffix :  _dx_info
# dimensions :  (95743, 260)
# iteration number 3
# suffix :  radiology
# dimensions :  (307208, 5)

# %%
holdingdf = pd.DataFrame()
cohort2dta = merge_lists(list_)
# Out:
# 0
# 1
# merging first list slice:  1
#     patient_id  encounter_id enc_eio_encounter visit_status_1_encounter  \
# 21          99       5169683                 O                Completed
#
#    visit_status_2_encounter visit_status_3_encounter visit_status_4_encounter  \
# 21                      NaN                      NaN                      NaN
#
#        adm_date_d_encounter    disc_date_d_encounter   start_date_d_encounter  \
# 21  2013-04-06 00:00:00.000  2013-04-06 00:00:00.000  2013-04-06 00:00:00.000
#
#        end_date_d_encounter     admit_source_1_encounter  \
# 21  2013-04-06 00:00:00.000  Clinic or Physicians Office
#
#    admit_source_2_encounter admit_source_3_encounter disch_disp_1_encounter  \
# 21                      NaN                      NaN                    NaN
#
#    disch_disp_2_encounter disch_disp_3_encounter  zip_d_encounter  \
# 21                    NaN                    NaN           149109
#
#      enc_fin_class_encounter
# 21  Blue Cross / Blue Shield
# 2
# merging next list slice:  2
#    patient_id  encounter_id dx_1_dx_info  \
# 2          99       5169683        162.3
#
#                                    dx_desc_1_dx_info  dx1_rank_dx_info  \
# 2  MALIGNANT NEOPLASM OF UPPER LOBE BRONCHUS OR LUNG               1.0
#
#   dx_2_dx_info                                 dx_desc_2_dx_info  \
# 2       793.19  OTHER NONSPECIFIC ABNORMAL FINDING OF LUNG FIELD
#
#    dx2_rank_dx_info dx_3_dx_info dx_desc_3_dx_info        ...          \
# 2               2.0          NaN               NaN        ...
#
#    dx83_rank_dx_info dx_84_dx_info dx_desc_84_dx_info  dx84_rank_dx_info  \
# 2                NaN           NaN                NaN                NaN
#
#   dx_85_dx_info dx_desc_85_dx_info  dx85_rank_dx_info dx_86_dx_info  \
# 2           NaN                NaN                NaN           NaN
#
#   dx_desc_86_dx_info  dx86_rank_dx_info
# 2                NaN                NaN
#
# [1 rows x 260 columns]
# 3
# merging next list slice:  3
#     patient_id  encounter_id  order_proc_id_deidradiology  \
# 10     1681824       3599599                       727666
#
#    ordering_date_offradiology   exam_typeradiology
# 10    2012-12-29 00:00:00.000  XR Chest PA/Lateral

# %%
cohort2dta.head()
# Out:
#    patient_id  age_at_last_encounter_patient gender_patient  \
# 0     1843306                           76.0              F
# 1     1843306                           76.0              F
# 2     1843306                           76.0              F
# 3     1843306                           76.0              F
# 4     1843306                           76.0              F
#
#              race_patient       ethnicity_patient  date_of_death_d_patient  \
# 0  Black/African-American  Not Hispanic or Latino  2015-02-22 00:00:00.000
# 1  Black/African-American  Not Hispanic or Latino  2015-02-22 00:00:00.000
# 2  Black/African-American  Not Hispanic or Latino  2015-02-22 00:00:00.000
# 3  Black/African-American  Not Hispanic or Latino  2015-02-22 00:00:00.000
# 4  Black/African-American  Not Hispanic or Latino  2015-02-22 00:00:00.000
#
#    encounter_id enc_eio_encounter visit_status_1_encounter  \
# 0       7872100                 I                Completed
# 1       7872100                 I                Completed
# 2       7872100                 I                Completed
# 3       7872100                 I                Completed
# 4       7872100                 I                Completed
#
#   visit_status_2_encounter              ...              dx84_rank_dx_info  \
# 0                 Canceled              ...                            NaN
# 1                 Canceled              ...                            NaN
# 2                 Canceled              ...                            NaN
# 3                 Canceled              ...                            NaN
# 4                 Canceled              ...                            NaN
#
#   dx_85_dx_info dx_desc_85_dx_info dx85_rank_dx_info dx_86_dx_info  \
# 0           NaN                NaN               NaN           NaN
# 1           NaN                NaN               NaN           NaN
# 2           NaN                NaN               NaN           NaN
# 3           NaN                NaN               NaN           NaN
# 4           NaN                NaN               NaN           NaN
#
#   dx_desc_86_dx_info dx86_rank_dx_info order_proc_id_deidradiology  \
# 0                NaN               NaN                    296814.0
# 1                NaN               NaN                    315456.0
# 2                NaN               NaN                    362063.0
# 3                NaN               NaN                    395686.0
# 4                NaN               NaN                    493692.0
#
#   ordering_date_offradiology            exam_typeradiology
# 0    2013-10-11 00:00:00.000         XR Port Chest, 1 View
# 1    2013-10-11 00:00:00.000                    CT Head wo
# 2    2013-10-11 00:00:00.000        CT Neck Soft Tissue wo
# 3    2013-10-11 00:00:00.000                    CT Head wo
# 4    2013-10-11 00:00:00.000  CT Chest, Abdomen, Pelvis wo
#
# [5 rows x 285 columns]

# %%
cohort2dta.to_csv(join(mypath,"merged_cohort2_sampled.csv"),sep="|")

# %% [markdown]
# # Joining to rad notes
#
# string dict is "encounter_id" and "order_proc_id_deid"

# %%
# read csvs if skipping above
cohort1total=pd.read_csv("Z:/FINAL OUTPUT v2/merged_cohort1_withcohort2.csv",sep="|")
cohort2dta=pd.read_csv("Z:/FINAL OUTPUT v2/merged_cohort2_sampled.csv",sep="|")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (19,21,22,116,119,120,122,123,125,126,128,129,131,132,134,135,137,138,140,141,143,144,146,147,149,150,152,153,155,156,158,159,161,162,164,165,167,168,170,171,173,174,176,177,179,180,182,183,185,186,188,189,191,192,194,195,197,198,200,201,203,204,206,207,209,210,212,213,215,216,218,219,221,222,224,225,227,228) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (6,11,12,18,19,21,22,37,40,43,46,49,52,55,58,67,68,70,71,73,74,76,77,79,80,82,83,85,86,88,89,91,92,94,95,97,98,100,101,103,104,106,107,109,110,112,113,115,116,118,119,121,122,124,125,127,128,130,131,133,134,136,137,139,140,142,143,145,146,148,149,151,152,154,155,157,158,160,161,163,164,166,167,169,170,172,173,175,176,178,179,181,182,184,185,187,188,190,191,193,194,196,197,199,200,202,203,205,206,208,209,211,212,214,215,217,218,220,221,223,224,226,227,230,233,236,239,242,245,248,250,251,253,254,256,257,259,260,262,263,265,266,268,269,271,272,274,275,277,278,280,281) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# extract encounter_id from notes
mypathnotes = "Z:/notes v2/"
onlyfilesnotes = [join(mypathnotes,f) for f in listdir(mypathnotes) if isfile(join(mypathnotes, f))]
onlyfilesnotes_sorted = sorted(onlyfilesnotes, key=lambda x:(x!="cohort", x))
print(onlyfilesnotes_sorted)
# Out:
# ['Z:/notes v2/cohort1_deid_df.csv', 'Z:/notes v2/cohort1_deid_df_editedforchecks.xlsx', 'Z:/notes v2/cohort2_deid_df.csv', 'Z:/notes v2/cohort_1_v2.zip', 'Z:/notes v2/cohort_2_v2.zip', 'Z:/notes v2/parsing_draft_v2.py']

# %%
# cohort 1
notes1 = pd.read_csv(onlyfilesnotes_sorted[0],index_col=None, header=0,sep=",")
notes1.columns = [x.lower() for x in notes1.columns]

# %%
# cohort 2
notes2 = pd.read_csv(onlyfilesnotes_sorted[2],index_col=None, header=0,sep=",",error_bad_lines=False)
notes2.columns = [x.lower() for x in notes2.columns]

# %%
# split 1
notes1[['encounter_id','order_proc_id_deid']] = notes1['patient'].str.split('_',expand=True)

# split2
notes2[['encounter_id','order_proc_id_deid']] = notes2['patient'].str.split('_',expand=True)

# %%
# ensure int type
results = [int(i) for i in notes1.encounter_id]
notes1.encounter_id = results

resultsorder = [int(i) for i in notes1.order_proc_id_deid]
notes1.order_proc_id_deid = resultsorder

# %%
# ensure int type
results = [int(i) for i in notes2.encounter_id]
notes2.encounter_id = results

resultsorder = [int(i) for i in notes2.order_proc_id_deid]
notes2.order_proc_id_deid = resultsorader

# %%
notes1[notes1.encounter_id==5035743]
# Out:
#    unnamed: 0              scantype                scandate  \
# 0           0  XR CHEST PA/LATERAL,  2014-10-18**]> 9:58 AM
#
#                                             clininfo            technique  \
# 0  **NAME<BBB> **AGE<in 60s> years old. Status po...  XR CHEST PA/LATERAL
#
#                   comparison  \
# 0  **DATE<[**2014-09-20**]>.
#
#                                             findings  \
# 0  No pneumothorax.  Irregular opacity along the ...
#
#                                          impressions  \
# 0  No pneumothorax.  Nonspecific air space opacit...
#
#                                              elecsig           patient  \
# 0  **DATE<[**2014-10-18**]> 12:13 PM [**Doctor Fi...   5035743_1018855
#
#                                              rawtext  encounter_id  \
# 0  XR CHEST PA/LATERAL, **DATE<[**2014-10-18**]> ...       5035743
#
#    order_proc_id_deid
# 0             1018855

# %%
print(cohort1total[cohort1total.encounter_id==5035743].columns)
# Out:
# Index(['Unnamed: 0', 'patient_id', 'age_at_last_encounter_patient',
#        'gender_patient', 'race_patient', 'ethnicity_patient',
#        'date_of_death_d_patient', 'encounter_id', 'enc_eio_encounter',
#        'visit_status_1_encounter',
#        ...
#        'dx83_rank_dx_info', 'dx_84_dx_info', 'dx_desc_84_dx_info',
#        'dx84_rank_dx_info', 'dx_85_dx_info', 'dx_desc_85_dx_info',
#        'dx85_rank_dx_info', 'dx_86_dx_info', 'dx_desc_86_dx_info',
#        'dx86_rank_dx_info'],
#       dtype='object', length=287)

# %% [markdown]
# # KC NOTE
#
# Still not matching on the order id. Not sure if missign something there.

# %% [markdown]
# ### Now join notes for cohort1

# %%
cohort1_dta_notes = pd.merge(cohort1total, notes1, on = 'encounter_id',how="left")
# cohort1_dta_notes = pd.merge(cohort1_dta_notes, notes2, on = 'encounter_id',how="left")
# pd.merge(cohort1total[cohort1total.encounter_id==5035743], notes1, on = 'encounter_id',how="left")[['patient_id','encounter_id','impressions']]

# %%
cohort1_dta_notes
# Out:
#        Unnamed: 0  patient_id  age_at_last_encounter_patient gender_patient  \
# 0               0       32124                           90.0              F
# 1               1       74912                           63.0              F
# 2               2       81545                           65.0              M
# 3               3       93110                           47.0              F
# 4               4      118647                           52.0              F
# 5               5      122487                           43.0              M
# 6               6      122522                           74.0              M
# 7               7      136921                           57.0              F
# 8               8      137154                           54.0              F
# 9               9      140791                           50.0              M
# 10             10      140791                           50.0              M
# 11             11      143528                           72.0              F
# 12             12      143528                           72.0              F
# 13             13      148260                           71.0              M
# 14             14      158414                           66.0              F
# 15             15      174454                           83.0              M
# 16             16      174454                           83.0              M
# 17             17      174454                           83.0              M
# 18             18      174454                           83.0              M
# 19             19      239207                           32.0              F
# 20             20      239207                           32.0              F
# 21             21      335825                           42.0              F
# 22             22      360469                           65.0              M
# 23             23      360469                           65.0              M
# 24             24      360469                           65.0              M
# 25             25      360469                           65.0              M
# 26             26      360469                           65.0              M
# 27             27      360469                           65.0              M
# 28             28      498795                           59.0              M
# 29             29      498795                           59.0              M
# ...           ...         ...                            ...            ...
# 59988       59948     2740460                           40.0              M
# 59989       59949     2740460                           40.0              M
# 59990       59950     2740460                           40.0              M
# 59991       59951     2740460                           40.0              M
# 59992       59952     2740460                           40.0              M
# 59993       59953     2740460                           40.0              M
# 59994       59954     2740460                           40.0              M
# 59995       59955     2740460                           40.0              M
# 59996       59956     2740460                           40.0              M
# 59997       59957     2740460                           40.0              M
# 59998       59958     2779581                           74.0              M
# 59999       59959     2779581                           74.0              M
# 60000       59960     2779581                           74.0              M
# 60001       59961     2849686                           56.0              M
# 60002       59962     2849686                           56.0              M
# 60003       59963     2849686                           56.0              M
# 60004       59964     2959602                           64.0              M
# 60005       59965     2959602                           64.0              M
# 60006       59966     2959602                           64.0              M
# 60007       59967     2959602                           64.0              M
# 60008       59968     2959602                           64.0              M
# 60009       59969     2959602                           64.0              M
# 60010       59970     2959602                           64.0              M
# 60011       59971     2959602                           64.0              M
# 60012       59972     2959602                           64.0              M
# 60013       59973     2959602                           64.0              M
# 60014       59974     2959602                           64.0              M
# 60015       59975     2959602                           64.0              M
# 60016       59976     2959602                           64.0              M
# 60017       59977     2959602                           64.0              M
#
#                  race_patient       ethnicity_patient  \
# 0                       White  Not Hispanic or Latino
# 1      Black/African-American  Not Hispanic or Latino
# 2                       White  Not Hispanic or Latino
# 3      Black/African-American  Not Hispanic or Latino
# 4      Black/African-American  Not Hispanic or Latino
# 5      Black/African-American  Not Hispanic or Latino
# 6      Black/African-American  Not Hispanic or Latino
# 7      Black/African-American  Not Hispanic or Latino
# 8      Black/African-American  Not Hispanic or Latino
# 9      Black/African-American  Not Hispanic or Latino
# 10     Black/African-American  Not Hispanic or Latino
# 11     Black/African-American  Not Hispanic or Latino
# 12     Black/African-American  Not Hispanic or Latino
# 13                      White      Hispanic or Latino
# 14     Black/African-American  Not Hispanic or Latino
# 15     Black/African-American  Not Hispanic or Latino
# 16     Black/African-American  Not Hispanic or Latino
# 17     Black/African-American  Not Hispanic or Latino
# 18     Black/African-American  Not Hispanic or Latino
# 19     Black/African-American  Not Hispanic or Latino
# 20     Black/African-American  Not Hispanic or Latino
# 21     Black/African-American  Not Hispanic or Latino
# 22     Black/African-American  Not Hispanic or Latino
# 23     Black/African-American  Not Hispanic or Latino
# 24     Black/African-American  Not Hispanic or Latino
# 25     Black/African-American  Not Hispanic or Latino
# 26     Black/African-American  Not Hispanic or Latino
# 27     Black/African-American  Not Hispanic or Latino
# 28     Black/African-American  Not Hispanic or Latino
# 29     Black/African-American  Not Hispanic or Latino
# ...                       ...                     ...
# 59988                   White  Not Hispanic or Latino
# 59989                   White  Not Hispanic or Latino
# 59990                   White  Not Hispanic or Latino
# 59991                   White  Not Hispanic or Latino
# 59992                   White  Not Hispanic or Latino
# 59993                   White  Not Hispanic or Latino
# 59994                   White  Not Hispanic or Latino
# 59995                   White  Not Hispanic or Latino
# 59996                   White  Not Hispanic or Latino
# 59997                   White  Not Hispanic or Latino
# 59998                   White  Not Hispanic or Latino
# 59999                   White  Not Hispanic or Latino
# 60000                   White  Not Hispanic or Latino
# 60001  Black/African-American  Not Hispanic or Latino
# 60002  Black/African-American  Not Hispanic or Latino
# 60003  Black/African-American  Not Hispanic or Latino
# 60004  Black/African-American  Not Hispanic or Latino
# 60005  Black/African-American  Not Hispanic or Latino
# 60006  Black/African-American  Not Hispanic or Latino
# 60007  Black/African-American  Not Hispanic or Latino
# 60008  Black/African-American  Not Hispanic or Latino
# 60009  Black/African-American  Not Hispanic or Latino
# 60010  Black/African-American  Not Hispanic or Latino
# 60011  Black/African-American  Not Hispanic or Latino
# 60012  Black/African-American  Not Hispanic or Latino
# 60013  Black/African-American  Not Hispanic or Latino
# 60014  Black/African-American  Not Hispanic or Latino
# 60015  Black/African-American  Not Hispanic or Latino
# 60016  Black/African-American  Not Hispanic or Latino
# 60017  Black/African-American  Not Hispanic or Latino
#
#        date_of_death_d_patient encounter_id enc_eio_encounter  \
# 0                          NaN      5039107                 O
# 1                          NaN      5237464                 O
# 2      2015-06-21 00:00:00.000      4429153                 O
# 3      2013-04-07 00:00:00.000      5226111                 O
# 4                          NaN      6862790                 O
# 5                          NaN      4875026                 O
# 6      2014-04-28 00:00:00.000      5019248                 O
# 7                          NaN      4529264                 O
# 8                          NaN      5489406                 O
# 9                          NaN      4492370                 O
# 10                         NaN      4974301                 O
# 11                         NaN      4093888                 O
# 12                         NaN      5900499                 O
# 13                         NaN      4812254                 O
# 14                         NaN      4652707                 O
# 15     2014-05-27 00:00:00.000      4269709                 O
# 16     2014-05-27 00:00:00.000      4672267                 O
# 17     2014-05-27 00:00:00.000      4672267                 O
# 18     2014-05-27 00:00:00.000      5247408                 O
# 19     2013-01-12 00:00:00.000      5197877                 E
# 20     2013-01-12 00:00:00.000      5197877                 E
# 21     2013-03-17 00:00:00.000      5086417                 O
# 22                         NaN      5035743                 O
# 23                         NaN      5035743                 O
# 24                         NaN      5174229                 O
# 25                         NaN      5317316                 O
# 26                         NaN      5317316                 O
# 27                         NaN      6988808                 O
# 28                         NaN      4468320                 O
# 29                         NaN      5750870                 O
# ...                        ...          ...               ...
# 59988                      NaN     11657247                 I
# 59989                      NaN     12529024                 O
# 59990                      NaN     12529024                 O
# 59991                      NaN     12584673                 I
# 59992                      NaN     12584673                 I
# 59993                      NaN     12584673                 I
# 59994                      NaN     12584673                 I
# 59995                      NaN     12584673                 I
# 59996                      NaN     12584673                 I
# 59997                      NaN     12584673                 I
# 59998                      NaN     12521405                 O
# 59999                      NaN     12521405                 O
# 60000                      NaN     12580704                 O
# 60001                      NaN     12234386                 O
# 60002                      NaN     12234386                 O
# 60003                      NaN     12234386                 O
# 60004  2018-12-08 00:00:00.000     12269769                 I
# 60005  2018-12-08 00:00:00.000     12269769                 I
# 60006  2018-12-08 00:00:00.000     12269769                 I
# 60007  2018-12-08 00:00:00.000     12269769                 I
# 60008  2018-12-08 00:00:00.000     12269769                 I
# 60009  2018-12-08 00:00:00.000     12269769                 I
# 60010  2018-12-08 00:00:00.000     12269769                 I
# 60011  2018-12-08 00:00:00.000     12269769                 I
# 60012  2018-12-08 00:00:00.000     12269769                 I
# 60013  2018-12-08 00:00:00.000     12269769                 I
# 60014  2018-12-08 00:00:00.000     12345049                 I
# 60015  2018-12-08 00:00:00.000     12345049                 I
# 60016  2018-12-08 00:00:00.000     12345049                 I
# 60017  2018-12-08 00:00:00.000     12345049                 I
#
#       visit_status_1_encounter         ...          scandate_y clininfo_y  \
# 0                    Completed         ...                 NaN        NaN
# 1                    Completed         ...                 NaN        NaN
# 2                    Completed         ...                 NaN        NaN
# 3                    Completed         ...                 NaN        NaN
# 4                    Completed         ...                 NaN        NaN
# 5                    Completed         ...                 NaN        NaN
# 6                    Completed         ...                 NaN        NaN
# 7                    Completed         ...                 NaN        NaN
# 8                    Completed         ...                 NaN        NaN
# 9                    Completed         ...                 NaN        NaN
# 10                   Completed         ...                 NaN        NaN
# 11                   Completed         ...                 NaN        NaN
# 12                   Completed         ...                 NaN        NaN
# 13                   Completed         ...                 NaN        NaN
# 14                   Completed         ...                 NaN        NaN
# 15                   Completed         ...                 NaN        NaN
# 16                   Completed         ...                 NaN        NaN
# 17                   Completed         ...                 NaN        NaN
# 18                   Completed         ...                 NaN        NaN
# 19                   Completed         ...                 NaN        NaN
# 20                   Completed         ...                 NaN        NaN
# 21                   Completed         ...                 NaN        NaN
# 22                   Completed         ...                 NaN        NaN
# 23                   Completed         ...                 NaN        NaN
# 24                   Completed         ...                 NaN        NaN
# 25                   Completed         ...                 NaN        NaN
# 26                   Completed         ...                 NaN        NaN
# 27                   Completed         ...                 NaN        NaN
# 28                   Completed         ...                 NaN        NaN
# 29                   Completed         ...                 NaN        NaN
# ...                        ...         ...                 ...        ...
# 59988                Completed         ...                 NaN        NaN
# 59989                Completed         ...                 NaN        NaN
# 59990                Completed         ...                 NaN        NaN
# 59991                  No Show         ...                 NaN        NaN
# 59992                  No Show         ...                 NaN        NaN
# 59993                  No Show         ...                 NaN        NaN
# 59994                  No Show         ...                 NaN        NaN
# 59995                  No Show         ...                 NaN        NaN
# 59996                  No Show         ...                 NaN        NaN
# 59997                  No Show         ...                 NaN        NaN
# 59998                Completed         ...                 NaN        NaN
# 59999                Completed         ...                 NaN        NaN
# 60000                Completed         ...                 NaN        NaN
# 60001                  No Show         ...                 NaN        NaN
# 60002                  No Show         ...                 NaN        NaN
# 60003                  No Show         ...                 NaN        NaN
# 60004                Completed         ...                 NaN        NaN
# 60005                Completed         ...                 NaN        NaN
# 60006                Completed         ...                 NaN        NaN
# 60007                Completed         ...                 NaN        NaN
# 60008                Completed         ...                 NaN        NaN
# 60009                Completed         ...                 NaN        NaN
# 60010                Completed         ...                 NaN        NaN
# 60011                Completed         ...                 NaN        NaN
# 60012                Completed         ...                 NaN        NaN
# 60013                Completed         ...                 NaN        NaN
# 60014                  No Show         ...                 NaN        NaN
# 60015                  No Show         ...                 NaN        NaN
# 60016                  No Show         ...                 NaN        NaN
# 60017                  No Show         ...                 NaN        NaN
#
#        technique_y comparison_y findings_y impressions_y elecsig_y patient_y  \
# 0              NaN          NaN        NaN           NaN       NaN       NaN
# 1              NaN          NaN        NaN           NaN       NaN       NaN
# 2              NaN          NaN        NaN           NaN       NaN       NaN
# 3              NaN          NaN        NaN           NaN       NaN       NaN
# 4              NaN          NaN        NaN           NaN       NaN       NaN
# 5              NaN          NaN        NaN           NaN       NaN       NaN
# 6              NaN          NaN        NaN           NaN       NaN       NaN
# 7              NaN          NaN        NaN           NaN       NaN       NaN
# 8              NaN          NaN        NaN           NaN       NaN       NaN
# 9              NaN          NaN        NaN           NaN       NaN       NaN
# 10             NaN          NaN        NaN           NaN       NaN       NaN
# 11             NaN          NaN        NaN           NaN       NaN       NaN
# 12             NaN          NaN        NaN           NaN       NaN       NaN
# 13             NaN          NaN        NaN           NaN       NaN       NaN
# 14             NaN          NaN        NaN           NaN       NaN       NaN
# 15             NaN          NaN        NaN           NaN       NaN       NaN
# 16             NaN          NaN        NaN           NaN       NaN       NaN
# 17             NaN          NaN        NaN           NaN       NaN       NaN
# 18             NaN          NaN        NaN           NaN       NaN       NaN
# 19             NaN          NaN        NaN           NaN       NaN       NaN
# 20             NaN          NaN        NaN           NaN       NaN       NaN
# 21             NaN          NaN        NaN           NaN       NaN       NaN
# 22             NaN          NaN        NaN           NaN       NaN       NaN
# 23             NaN          NaN        NaN           NaN       NaN       NaN
# 24             NaN          NaN        NaN           NaN       NaN       NaN
# 25             NaN          NaN        NaN           NaN       NaN       NaN
# 26             NaN          NaN        NaN           NaN       NaN       NaN
# 27             NaN          NaN        NaN           NaN       NaN       NaN
# 28             NaN          NaN        NaN           NaN       NaN       NaN
# 29             NaN          NaN        NaN           NaN       NaN       NaN
# ...            ...          ...        ...           ...       ...       ...
# 59988          NaN          NaN        NaN           NaN       NaN       NaN
# 59989          NaN          NaN        NaN           NaN       NaN       NaN
# 59990          NaN          NaN        NaN           NaN       NaN       NaN
# 59991          NaN          NaN        NaN           NaN       NaN       NaN
# 59992          NaN          NaN        NaN           NaN       NaN       NaN
# 59993          NaN          NaN        NaN           NaN       NaN       NaN
# 59994          NaN          NaN        NaN           NaN       NaN       NaN
# 59995          NaN          NaN        NaN           NaN       NaN       NaN
# 59996          NaN          NaN        NaN           NaN       NaN       NaN
# 59997          NaN          NaN        NaN           NaN       NaN       NaN
# 59998          NaN          NaN        NaN           NaN       NaN       NaN
# 59999          NaN          NaN        NaN           NaN       NaN       NaN
# 60000          NaN          NaN        NaN           NaN       NaN       NaN
# 60001          NaN          NaN        NaN           NaN       NaN       NaN
# 60002          NaN          NaN        NaN           NaN       NaN       NaN
# 60003          NaN          NaN        NaN           NaN       NaN       NaN
# 60004          NaN          NaN        NaN           NaN       NaN       NaN
# 60005          NaN          NaN        NaN           NaN       NaN       NaN
# 60006          NaN          NaN        NaN           NaN       NaN       NaN
# 60007          NaN          NaN        NaN           NaN       NaN       NaN
# 60008          NaN          NaN        NaN           NaN       NaN       NaN
# 60009          NaN          NaN        NaN           NaN       NaN       NaN
# 60010          NaN          NaN        NaN           NaN       NaN       NaN
# 60011          NaN          NaN        NaN           NaN       NaN       NaN
# 60012          NaN          NaN        NaN           NaN       NaN       NaN
# 60013          NaN          NaN        NaN           NaN       NaN       NaN
# 60014          NaN          NaN        NaN           NaN       NaN       NaN
# 60015          NaN          NaN        NaN           NaN       NaN       NaN
# 60016          NaN          NaN        NaN           NaN       NaN       NaN
# 60017          NaN          NaN        NaN           NaN       NaN       NaN
#
#       rawtext_y order_proc_id_deid_y
# 0           NaN                  NaN
# 1           NaN                  NaN
# 2           NaN                  NaN
# 3           NaN                  NaN
# 4           NaN                  NaN
# 5           NaN                  NaN
# 6           NaN                  NaN
# 7           NaN                  NaN
# 8           NaN                  NaN
# 9           NaN                  NaN
# 10          NaN                  NaN
# 11          NaN                  NaN
# 12          NaN                  NaN
# 13          NaN                  NaN
# 14          NaN                  NaN
# 15          NaN                  NaN
# 16          NaN                  NaN
# 17          NaN                  NaN
# 18          NaN                  NaN
# 19          NaN                  NaN
# 20          NaN                  NaN
# 21          NaN                  NaN
# 22          NaN                  NaN
# 23          NaN                  NaN
# 24          NaN                  NaN
# 25          NaN                  NaN
# 26          NaN                  NaN
# 27          NaN                  NaN
# 28          NaN                  NaN
# 29          NaN                  NaN
# ...         ...                  ...
# 59988       NaN                  NaN
# 59989       NaN                  NaN
# 59990       NaN                  NaN
# 59991       NaN                  NaN
# 59992       NaN                  NaN
# 59993       NaN                  NaN
# 59994       NaN                  NaN
# 59995       NaN                  NaN
# 59996       NaN                  NaN
# 59997       NaN                  NaN
# 59998       NaN                  NaN
# 59999       NaN                  NaN
# 60000       NaN                  NaN
# 60001       NaN                  NaN
# 60002       NaN                  NaN
# 60003       NaN                  NaN
# 60004       NaN                  NaN
# 60005       NaN                  NaN
# 60006       NaN                  NaN
# 60007       NaN                  NaN
# 60008       NaN                  NaN
# 60009       NaN                  NaN
# 60010       NaN                  NaN
# 60011       NaN                  NaN
# 60012       NaN                  NaN
# 60013       NaN                  NaN
# 60014       NaN                  NaN
# 60015       NaN                  NaN
# 60016       NaN                  NaN
# 60017       NaN                  NaN
#
# [60018 rows x 311 columns]

# %%
cohort1_dta_notes[cohort1_dta_notes.impressions.notnull()]

# %% [markdown]
# ### Now join notes for cohort2

# %%
cohort2_dta_notes = pd.merge(cohort2dta, notes2, on = 'encounter_id',how="left")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-bab2ba70c077> in <module>()
# ----> 1 cohort2_dta_notes = pd.merge(cohort2dta, notes2, on = 'encounter_id',how="left")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      56                          copy=copy, indicator=indicator,
#      57                          validate=validate)
# ---> 58     return op.get_result()
#      59
#      60
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     594             [(ldata, lindexers), (rdata, rindexers)],
#     595             axes=[llabels.append(rlabels), join_index],
# --> 596             concat_axis=0, copy=self.copy)
#     597
#     598         typ = self.left._constructor
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#    5201         else:
#    5202             b = make_block(
# -> 5203                 concatenate_join_units(join_units, concat_axis, copy=copy),
#    5204                 placement=placement)
#    5205         blocks.append(b)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in concatenate_join_units(join_units, concat_axis, copy)
#    5330     to_concat = [ju.get_reindexed_values(empty_dtype=empty_dtype,
#    5331                                          upcasted_na=upcasted_na)
# -> 5332                  for ju in join_units]
#    5333
#    5334     if len(to_concat) == 1:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in <listcomp>(.0)
#    5330     to_concat = [ju.get_reindexed_values(empty_dtype=empty_dtype,
#    5331                                          upcasted_na=upcasted_na)
# -> 5332                  for ju in join_units]
#    5333
#    5334     if len(to_concat) == 1:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in get_reindexed_values(self, empty_dtype, upcasted_na)
#    5630             for ax, indexer in self.indexers.items():
#    5631                 values = algos.take_nd(values, indexer, axis=ax,
# -> 5632                                        fill_value=fill_value)
#    5633
#    5634         return values
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\algorithms.py in take_nd(arr, indexer, axis, out, fill_value, mask_info, allow_fill)
#    1379             out = np.empty(out_shape, dtype=dtype)
#    1380
# -> 1381     func = _get_take_nd_function(arr.ndim, arr.dtype, out.dtype, axis=axis,
#    1382                                  mask_info=mask_info)
#    1383     func(arr, indexer, out, fill_value)
#
# KeyboardInterrupt:

# %%
cohort2_dta_notes[cohort2_dta_notes.impressions.notnull()]
# Out:
# Empty DataFrame
# Columns: [patient_id, age_at_last_encounter_patient, gender_patient, race_patient, ethnicity_patient, date_of_death_d_patient, encounter_id_encounter, enc_eio_encounter, visit_status_1_encounter, visit_status_2_encounter, visit_status_3_encounter, visit_status_4_encounter, adm_date_d_encounter, disc_date_d_encounter, start_date_d_encounter, end_date_d_encounter, admit_source_1_encounter, admit_source_2_encounter, admit_source_3_encounter, disch_disp_1_encounter, disch_disp_2_encounter, disch_disp_3_encounter, zip_d_encounter, enc_fin_class_encounter, encounter_id_encounter_provider, admitting_prov_id_encounter_provider, admitting_provider_department_encounter_provider, attnd_prov_id_encounter_provider, attending_department_encounter_provider, referring_prov_id_encounter_provider, referring_department_encounter_provider, contact_date_off_encounter_social, is_tobacco_user_encounter_social, tobacco_pak_per_dy_encounter_social, tobacco_used_years_encounter_social, tobacco_comment_encounter_social, smoking_quit_date_off_encounter_social, cigarettes_yn_encounter_social, pipes_yn_encounter_social, cigars_yn_encounter_social, snuff_yn_encounter_social, chew_yn_encounter_social, is_alcohol_user_encounter_social, alcohol_oz_per_wk_encounter_social, is_ill_drug_user_encounter_social, iv_drug_user_yn_encounter_social, illicit_drug_freq_encounter_social, is_sexually_actv_encounter_social, female_partner_yn_encounter_social, male_partner_yn_encounter_social, condom_yn_encounter_social, pill_yn_encounter_social, diaphragm_yn_encounter_social, iud_yn_encounter_social, surgical_yn_encounter_social, spermicide_yn_encounter_social, implant_yn_encounter_social, rhythm_yn_encounter_social, injection_yn_encounter_social, sponge_yn_encounter_social, inserts_yn_encounter_social, abstinence_yn_encounter_social, years_education_encounter_social, tob_src_c_encounter_social, alcohol_src_c_encounter_social, sex_src_c_encounter_social, alcohol_use_c_encounter_social, ill_drug_user_c_encounter_social, sexually_active_c_encounter_social, tobacco_user_encounter_social, smokeless_tob_use_c_encounter_social, smokeless_quit_date_off_encounter_social, smoking_tob_use_encounter_social, unknown_fam_hx_yn_encounter_social, smoking_start_date_off_encounter_social, encounter_id_dx_info, dx_1_dx_info, dx_desc_1_dx_info, dx1_rank_dx_info, dx_2_dx_info, dx_desc_2_dx_info, dx2_rank_dx_info, dx_3_dx_info, dx_desc_3_dx_info, dx3_rank_dx_info, dx_4_dx_info, dx_desc_4_dx_info, dx4_rank_dx_info, dx_5_dx_info, dx_desc_5_dx_info, dx5_rank_dx_info, dx_6_dx_info, dx_desc_6_dx_info, dx6_rank_dx_info, dx_7_dx_info, dx_desc_7_dx_info, dx7_rank_dx_info, dx_8_dx_info, dx_desc_8_dx_info, dx8_rank_dx_info, ...]
# Index: []
#
# [0 rows x 119 columns]
